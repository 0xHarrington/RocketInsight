# %%
import pandas as pd
import json
from web3 import Web3
from datetime import datetime, timedelta
import time
import sys
import json
from collections import Counter

# Connect to ETH blockchain with infura API key
w3 = Web3(Web3.HTTPProvider('https://mainnet.infura.io/v3/5f0c4998d7544ee1bb3f0dc297a6821c'))

# AAVE V3 ETH Mainnet Market Pool Address
contract_addr = '0x87870Bca3F3fD6335C3F4ce8392D69350B4fA4E2'

# Load ABI
with open("./abi.json") as f:
    pool_abi = json.load(f)
    
# Load Contract
aave_pool_contract = w3.eth.contract(address=contract_addr, abi=pool_abi)

# %%
def get_initial_depo_blockNum(aave_pool_contract, user_wallet_address):
    """
    Finds the lowest block number for rETH supply events related to a given user wallet address for AAVE v3.

    Parameters:
    - aave_pool_contract: The Aave pool contract instance from Web3.py.
    - user_wallet_address: The wallet address of the user as a string.

    Returns:
    - The lowest block number for the given user wallet address. Returns None if the user has no supply events.
    """
    # For some reason it doesnt work when user filter vs onBehalfOf
    log_filter = {
        'reserve': '0xae78736Cd615f374D3085123A210448E74Fc6393', #rETH token address
        'onBehalfOf': user_wallet_address,
    }
    
    logs = aave_pool_contract.events.Supply().get_logs(fromBlock='earliest',
                                                       toBlock='latest',
                                                       argument_filters=log_filter)
    if not logs:
        return 0
    
    return min(log['blockNumber'] for log in logs)

# %%
def fetch_logs(user_address_filter, aave_pool_contract, event_name, block_step = 100000):
    """
    Fetches logs for transactions filtered by user address and event type, from the latest block down to initial rETH deposit.

    Parameters:
    - user_address_filter: The user wallet address to filter the logs.
    - aave_pool_contract: The contract object to fetch logs from.
    - event_name: The name of the event to fetch {'Borrow', 'Repay', 'Withdraw', 'FlashLoan'}
    - block_step: The number of blocks to step back in each iteration (default is 100000).

    Returns:
    - A dataframe of formatted logs.
    """
    
    # Get target block
    target_block = get_initial_depo_blockNum(aave_pool_contract, user_address_filter)
    
    print(f'For User: {user_address_filter}\nFrom Block: {target_block}')

    # Dynamic print
    print(f'Fetching {event_name} events', end='')
    sys.stdout.flush()

    # Variables for looping
    logged_results = []
    target_log_count = float('inf')
    current_block = w3.eth.block_number    # Latest Block Number

    # Time
    start = time.time()

    # Loop counter
    iter_count = 0

    # Loop until target number reached or at first block
    while (len(logged_results) < target_log_count and current_block > target_block):
        print('.', end='')

        from_block = max(current_block - block_step, target_block)

        try:
            # Access event
            event = getattr(aave_pool_contract.events, event_name)()
            
            # Fetch logs for the current block
            if (event_name == 'FlashLoan'):
                current_logs = event.get_logs(
                    fromBlock=from_block,
                    toBlock=current_block,
                    argument_filters={'initiator': user_address_filter}
                )
            elif (event_name == 'Borrow'):
                current_logs = event.get_logs(
                    fromBlock=from_block,
                    toBlock=current_block,
                    argument_filters={'onBehalfOf': user_address_filter}
                )
            elif (event_name == 'Withdraw'):
                current_logs = event.get_logs(
                    fromBlock=from_block,
                    toBlock=current_block,
                    argument_filters={'to': user_address_filter}
                )
            else: #repay
                current_logs = event.get_logs(
                    fromBlock=from_block,
                    toBlock=current_block,
                    argument_filters={'user': user_address_filter}
                )

            # Format event logs
            for event in current_logs:
                formatted_log = format_event_log(event, event_name)

                # Add to aggregate log list
                logged_results.append(formatted_log)

            # Decrement block number
            current_block = from_block - 1

        except Exception as e:
            # Print exception and block number and break
            print(f"\nError fetching logs for block {current_block}: {e}")
            break

        # Increment iter
        iter_count += 1

    # Print time
    print('\nFetching complete.')
    print(f'Time Elapsed: {time.time() - start}\n')

    # Trim list
    if len(logged_results) > target_log_count:
           logged_results = logged_results[-target_log_count:]

    # Return dataframed logs
    return pd.DataFrame(logged_results)

def format_event_log(event, event_name):
    """
    Formats the log of an event based on its type.

    Parameters:
    - event: The event log to format.
    - event_name: The name of the event.

    Returns:
    - A dictionary containing formatted log attributes.
    """
    
    # Format common attrs
    log = {
        'Event Type': event_name,
        'Transaction Hash': event['transactionHash'].hex(),
        'Address': event['address'],
        'Block Hash': event['blockHash'].hex(),
        'Block Number': event['blockNumber'],
    }
    
    # if else tree for event specific attrs
    if event_name == 'Withdraw':
        log.update({
            'Reserve': event['args']['reserve'],
            'User': event['args']['user'],
            'To': event['args']['to'],
            'Amount': event['args']['amount']
        })
        
    elif event_name == 'Borrow':
        log.update({
            'Reserve': event['args']['reserve'],
            'On Behalf Of': event['args']['onBehalfOf'],
            'User': event['args']['user'],
            'Amount': event['args']['amount'],
            'Borrow Rate': event['args']['borrowRate']
        })
        
    elif event_name == 'Repay':
        log.update({
            'Reserve': event['args']['reserve'],
            'User': event['args']['user'],
            'Repayer': event['args']['repayer'],
            'Amount': event['args']['amount'],
            'useAtokens': str(event['args']['useATokens']),
            
        })
        
    elif event_name == 'FlashLoan':
        log.update({
            'Target': event['args']['target'],
            'Asset': event['args']['asset'],
            'Referral Code': str(event['args']['referralCode']),
            'Initiator': event['args']['initiator'],
            'Amount': event['args']['amount'],
            'Premium': event['args']['premium']
        })
    
    return log

# %%
# Map market name to pool contract address and abi filepath
contract_address_abi_map = {
    'AAVE': ('0x87870Bca3F3fD6335C3F4ce8392D69350B4fA4E2', './abi.json')
    # fill with rest
}

def user_history(user_addresses, markets):
    """
    Fetches the interaction history of users with specified lending and borrowing markets.
    
    Parameters:
    - user_addresses: List of user wallet addresses.
    - markets: List of market names to scrape.
    
    Returns:
    - A dictionary mapping each user address to a list of dataframes (one for each interaction type).
    """
    interaction_history = {user: [] for user in user_addresses}
    event_types = ['Withdraw', 'Borrow', 'Repay', 'FlashLoan']
    
    # Loop markets
    for market in markets:
        # Lookup contract address and abi filepath
        contract_address, abi_filepath = contract_address_abi_map[market]
        
        # Web3 setup
        with open(abi_filepath) as f:
            abi = json.load(f)

        smart_contract = w3.eth.contract(address=contract_address, abi=abi)
        
        # Loop user addresses
        for user_address in user_addresses:
            # Loop event types
            for event_type in event_types:
                logs_df = fetch_logs(user_address, smart_contract, event_type, block_step = 250000)
                interaction_history[user_address].append(logs_df)
            
    return interaction_history

# %%
# TEST USER HISTORY

# Load wallet address data for testing
addresses_df = pd.read_csv('user_wallet_addresses.csv')
user_wallet_addresses = addresses_df['User Wallet Addresses'].tolist()

interaction_list = user_history(user_wallet_addresses, ['AAVE'])
# Out:
# For User: 0xc83894aC498289E54FBE523c0ABFcbac8CeB1CaB
# From Block: 19099490
# Fetching Withdraw events..
# Fetching complete.
# Time Elapsed: 0.112945556640625
#
# For User: 0xc83894aC498289E54FBE523c0ABFcbac8CeB1CaB
# From Block: 19099490
# Fetching Borrow events..
# Fetching complete.
# Time Elapsed: 0.08099055290222168
#
# For User: 0xc83894aC498289E54FBE523c0ABFcbac8CeB1CaB
# From Block: 19099490
# Fetching Repay events..
# Fetching complete.
# Time Elapsed: 0.07064151763916016
#
# For User: 0xc83894aC498289E54FBE523c0ABFcbac8CeB1CaB
# From Block: 19099490
# Fetching FlashLoan events..
# Fetching complete.
# Time Elapsed: 1.6830947399139404
#
# For User: 0x1A415A3b77ED38B683Db945dc83F53ECda26F716
# From Block: 19099534
# Fetching Withdraw events..
# Fetching complete.
# Time Elapsed: 0.08647990226745605
#
# For User: 0x1A415A3b77ED38B683Db945dc83F53ECda26F716
# From Block: 19099534
# Fetching Borrow events..
# Fetching complete.
# Time Elapsed: 0.16286277770996094
#
# For User: 0x1A415A3b77ED38B683Db945dc83F53ECda26F716
# From Block: 19099534
# Fetching Repay events..
# Fetching complete.
# Time Elapsed: 0.057578086853027344
#
# For User: 0x1A415A3b77ED38B683Db945dc83F53ECda26F716
# From Block: 19099534
# Fetching FlashLoan events..
# Fetching complete.
# Time Elapsed: 1.4653127193450928
#
# For User: 0xecCaCB54ffF224316f0ba589760624186FcbeA27
# From Block: 19100701
# Fetching Withdraw events..
# Fetching complete.
# Time Elapsed: 0.09639143943786621
#
# For User: 0xecCaCB54ffF224316f0ba589760624186FcbeA27
# From Block: 19100701
# Fetching Borrow events..
# Fetching complete.
# Time Elapsed: 0.0690004825592041
#
# For User: 0xecCaCB54ffF224316f0ba589760624186FcbeA27
# From Block: 19100701
# Fetching Repay events..
# Fetching complete.
# Time Elapsed: 0.07367324829101562
#
# For User: 0xecCaCB54ffF224316f0ba589760624186FcbeA27
# From Block: 19100701
# Fetching FlashLoan events..
# Fetching complete.
# Time Elapsed: 1.2861998081207275
#
# For User: 0x1aEcea38B8626EEB3748234343cff427268Dd487
# From Block: 18386174
# Fetching Withdraw events.....
# Fetching complete.
# Time Elapsed: 2.616848945617676
#
# For User: 0x1aEcea38B8626EEB3748234343cff427268Dd487
# From Block: 18386174
# Fetching Borrow events.....
# Fetching complete.
# Time Elapsed: 1.6380369663238525
#
# For User: 0x1aEcea38B8626EEB3748234343cff427268Dd487
# From Block: 18386174
# Fetching Repay events.....
# Fetching complete.
# Time Elapsed: 1.1842169761657715
#
# For User: 0x1aEcea38B8626EEB3748234343cff427268Dd487
# From Block: 18386174
# Fetching FlashLoan events.....
# Fetching complete.
# Time Elapsed: 5.064266920089722
#
# For User: 0x3D2b8879f97e413b2609F9844A5fc8dB8FE4f6F8
# From Block: 18148459
# Fetching Withdraw events......
# Fetching complete.
# Time Elapsed: 0.2713754177093506
#
# For User: 0x3D2b8879f97e413b2609F9844A5fc8dB8FE4f6F8
# From Block: 18148459
# Fetching Borrow events......
# Fetching complete.
# Time Elapsed: 0.3339090347290039
#
# For User: 0x3D2b8879f97e413b2609F9844A5fc8dB8FE4f6F8
# From Block: 18148459
# Fetching Repay events......
# Fetching complete.
# Time Elapsed: 0.2848935127258301
#
# For User: 0x3D2b8879f97e413b2609F9844A5fc8dB8FE4f6F8
# From Block: 18148459
# Fetching FlashLoan events......
# Fetching complete.
# Time Elapsed: 5.597048282623291
#
# For User: 0xADC0A53095A0af87F3aa29FE0715B5c28016364e
# From Block: 0
# Fetching Withdraw events..............................................................................
# Fetching complete.
# Time Elapsed: 7.541032314300537
#
# For User: 0xADC0A53095A0af87F3aa29FE0715B5c28016364e
# From Block: 0
# Fetching Borrow events..............................................................................
# Fetching complete.
# Time Elapsed: 5.142297029495239
#
# For User: 0xADC0A53095A0af87F3aa29FE0715B5c28016364e
# From Block: 0
# Fetching Repay events..............................................................................
# Fetching complete.
# Time Elapsed: 3.5652732849121094
#
# For User: 0xADC0A53095A0af87F3aa29FE0715B5c28016364e
# From Block: 0
# Fetching FlashLoan events..............................................................................
# Fetching complete.
# Time Elapsed: 12.043564558029175
#
# For User: 0x00000000032962B51589768828ad878876299E14
# From Block: 19077272
# Fetching Withdraw events..
# Fetching complete.
# Time Elapsed: 1.0952253341674805
#
# For User: 0x00000000032962B51589768828ad878876299E14
# From Block: 19077272
# Fetching Borrow events..
# Fetching complete.
# Time Elapsed: 0.9695501327514648
#
# For User: 0x00000000032962B51589768828ad878876299E14
# From Block: 19077272
# Fetching Repay events..
# Fetching complete.
# Time Elapsed: 0.33952975273132324
#
# For User: 0x00000000032962B51589768828ad878876299E14
# From Block: 19077272
# Fetching FlashLoan events..
# Fetching complete.
# Time Elapsed: 1.3352041244506836
#
# For User: 0x684566C9FFcAC7F6A04C3a9997000d2d58C00824
# From Block: 18633950
# Fetching Withdraw events....
# Fetching complete.
# Time Elapsed: 0.36978888511657715
#
# For User: 0x684566C9FFcAC7F6A04C3a9997000d2d58C00824
# From Block: 18633950
# Fetching Borrow events....
# Fetching complete.
# Time Elapsed: 0.21927404403686523
#
# For User: 0x684566C9FFcAC7F6A04C3a9997000d2d58C00824
# From Block: 18633950
# Fetching Repay events....
# Fetching complete.
# Time Elapsed: 0.17755532264709473
#
# For User: 0x684566C9FFcAC7F6A04C3a9997000d2d58C00824
# From Block: 18633950
# Fetching FlashLoan events....
# Fetching complete.
# Time Elapsed: 3.6799521446228027
#
# For User: 0xA8b68E97121B011F38Aa236458ABe7c8B76A0E32
# From Block: 19117182
# Fetching Withdraw events..
# Fetching complete.
# Time Elapsed: 0.09549713134765625
#
# For User: 0xA8b68E97121B011F38Aa236458ABe7c8B76A0E32
# From Block: 19117182
# Fetching Borrow events..
# Fetching complete.
# Time Elapsed: 0.06169009208679199
#
# For User: 0xA8b68E97121B011F38Aa236458ABe7c8B76A0E32
# From Block: 19117182
# Fetching Repay events..
# Fetching complete.
# Time Elapsed: 0.07698774337768555
#
# For User: 0xA8b68E97121B011F38Aa236458ABe7c8B76A0E32
# From Block: 19117182
# Fetching FlashLoan events..
# Fetching complete.
# Time Elapsed: 1.2669715881347656
#
# For User: 0xaeF322446A35705a4D5959FBb3E9E7718533AD43
# From Block: 19119942
# Fetching Withdraw events..
# Fetching complete.
# Time Elapsed: 0.08519983291625977
#
# For User: 0xaeF322446A35705a4D5959FBb3E9E7718533AD43
# From Block: 19119942
# Fetching Borrow events..
# Fetching complete.
# Time Elapsed: 0.08237981796264648
#
# For User: 0xaeF322446A35705a4D5959FBb3E9E7718533AD43
# From Block: 19119942
# Fetching Repay events..
# Fetching complete.
# Time Elapsed: 0.08443903923034668
#
# For User: 0xaeF322446A35705a4D5959FBb3E9E7718533AD43
# From Block: 19119942
# Fetching FlashLoan events..
# Fetching complete.
# Time Elapsed: 1.3182060718536377
#
# For User: 0xa6381631e0634e97E23a80a3c57F9582aa959e16
# From Block: 18871531
# Fetching Withdraw events...
# Fetching complete.
# Time Elapsed: 0.7299959659576416
#
# For User: 0xa6381631e0634e97E23a80a3c57F9582aa959e16
# From Block: 18871531
# Fetching Borrow events...
# Fetching complete.
# Time Elapsed: 1.297879695892334
#
# For User: 0xa6381631e0634e97E23a80a3c57F9582aa959e16
# From Block: 18871531
# Fetching Repay events...
# Fetching complete.
# Time Elapsed: 0.8762829303741455
#
# For User: 0xa6381631e0634e97E23a80a3c57F9582aa959e16
# From Block: 18871531
# Fetching FlashLoan events...
# Fetching complete.
# Time Elapsed: 2.6575803756713867
#
# For User: 0x572372831A9d6B2E3ee8fa284505599e6125Fea9
# From Block: 19138101
# Fetching Withdraw events..
# Fetching complete.
# Time Elapsed: 0.09257006645202637
#
# For User: 0x572372831A9d6B2E3ee8fa284505599e6125Fea9
# From Block: 19138101
# Fetching Borrow events..
# Fetching complete.
# Time Elapsed: 0.21711301803588867
#
# For User: 0x572372831A9d6B2E3ee8fa284505599e6125Fea9
# From Block: 19138101
# Fetching Repay events..
# Fetching complete.
# Time Elapsed: 0.23736953735351562
#
# For User: 0x572372831A9d6B2E3ee8fa284505599e6125Fea9
# From Block: 19138101
# Fetching FlashLoan events..
# Fetching complete.
# Time Elapsed: 1.1769869327545166
#
# For User: 0xf9231D28B34CD77A08542f73ca87c4411B1b8B56
# From Block: 18029101
# Fetching Withdraw events......
# Fetching complete.
# Time Elapsed: 0.3361945152282715
#
# For User: 0xf9231D28B34CD77A08542f73ca87c4411B1b8B56
# From Block: 18029101
# Fetching Borrow events......
# Fetching complete.
# Time Elapsed: 0.3026902675628662
#
# For User: 0xf9231D28B34CD77A08542f73ca87c4411B1b8B56
# From Block: 18029101
# Fetching Repay events......
# Fetching complete.
# Time Elapsed: 0.24365806579589844
#
# For User: 0xf9231D28B34CD77A08542f73ca87c4411B1b8B56
# From Block: 18029101
# Fetching FlashLoan events......
# Fetching complete.
# Time Elapsed: 5.973413944244385
#
# For User: 0x78e96Be52e38b3FC3445A2ED34a6e586fFAb9631
# From Block: 18489769
# Fetching Withdraw events....
# Fetching complete.
# Time Elapsed: 0.36112284660339355
#
# For User: 0x78e96Be52e38b3FC3445A2ED34a6e586fFAb9631
# From Block: 18489769
# Fetching Borrow events....
# Fetching complete.
# Time Elapsed: 0.19483685493469238
#
# For User: 0x78e96Be52e38b3FC3445A2ED34a6e586fFAb9631
# From Block: 18489769
# Fetching Repay events....
# Fetching complete.
# Time Elapsed: 0.15902423858642578
#
# For User: 0x78e96Be52e38b3FC3445A2ED34a6e586fFAb9631
# From Block: 18489769
# Fetching FlashLoan events....
# Fetching complete.
# Time Elapsed: 4.419696569442749
#
# For User: 0x5E01C1d9f0198Ac4f02696e0A12CfA7969d172Da
# From Block: 0
# Fetching Withdraw events..............................................................................
# Fetching complete.
# Time Elapsed: 3.705087184906006
#
# For User: 0x5E01C1d9f0198Ac4f02696e0A12CfA7969d172Da
# From Block: 0
# Fetching Borrow events..............................................................................
# Fetching complete.
# Time Elapsed: 3.873993158340454
#
# For User: 0x5E01C1d9f0198Ac4f02696e0A12CfA7969d172Da
# From Block: 0
# Fetching Repay events..............................................................................
# Fetching complete.
# Time Elapsed: 3.188354969024658
#
# For User: 0x5E01C1d9f0198Ac4f02696e0A12CfA7969d172Da
# From Block: 0
# Fetching FlashLoan events..............................................................................
# Fetching complete.
# Time Elapsed: 12.366014242172241
#
# For User: 0x8F5915A19Eb2Ba78Bc90aD0317d9ed0d161CBfeC
# From Block: 19146177
# Fetching Withdraw events..
# Fetching complete.
# Time Elapsed: 0.10880041122436523
#
# For User: 0x8F5915A19Eb2Ba78Bc90aD0317d9ed0d161CBfeC
# From Block: 19146177
# Fetching Borrow events..
# Fetching complete.
# Time Elapsed: 0.13397884368896484
#
# For User: 0x8F5915A19Eb2Ba78Bc90aD0317d9ed0d161CBfeC
# From Block: 19146177
# Fetching Repay events..
# Fetching complete.
# Time Elapsed: 0.0702662467956543
#
# For User: 0x8F5915A19Eb2Ba78Bc90aD0317d9ed0d161CBfeC
# From Block: 19146177
# Fetching FlashLoan events..
# Fetching complete.
# Time Elapsed: 1.123488187789917
#
# For User: 0xEF8D1810dBf02E3558891E9960098C0588CbdcfC
# From Block: 18398446
# Fetching Withdraw events.....
# Fetching complete.
# Time Elapsed: 0.22766351699829102
#
# For User: 0xEF8D1810dBf02E3558891E9960098C0588CbdcfC
# From Block: 18398446
# Fetching Borrow events.....
# Fetching complete.
# Time Elapsed: 0.2577962875366211
#
# For User: 0xEF8D1810dBf02E3558891E9960098C0588CbdcfC
# From Block: 18398446
# Fetching Repay events.....
# Fetching complete.
# Time Elapsed: 0.35704827308654785
#
# For User: 0xEF8D1810dBf02E3558891E9960098C0588CbdcfC
# From Block: 18398446
# Fetching FlashLoan events.....
# Fetching complete.
# Time Elapsed: 5.028584003448486
#
# For User: 0x02e7B8511831B1b02d9018215a0f8f500Ea5c6B3
# From Block: 0
# Fetching Withdraw events..............................................................................
# Fetching complete.
# Time Elapsed: 7.2054221630096436
#
# For User: 0x02e7B8511831B1b02d9018215a0f8f500Ea5c6B3
# From Block: 0
# Fetching Borrow events..............................................................................
# Fetching complete.
# Time Elapsed: 4.944681167602539
#
# For User: 0x02e7B8511831B1b02d9018215a0f8f500Ea5c6B3
# From Block: 0
# Fetching Repay events..............................................................................
# Fetching complete.
# Time Elapsed: 4.596139907836914
#
# For User: 0x02e7B8511831B1b02d9018215a0f8f500Ea5c6B3
# From Block: 0
# Fetching FlashLoan events..............................................................................
# Fetching complete.
# Time Elapsed: 11.710208892822266
#
# For User: 0x7a0C9037fB4E51dd10a921E1eA8AAee07862F644
# From Block: 19060961
# Fetching Withdraw events..
# Fetching complete.
# Time Elapsed: 0.2001018524169922
#
# For User: 0x7a0C9037fB4E51dd10a921E1eA8AAee07862F644
# From Block: 19060961
# Fetching Borrow events..
# Fetching complete.
# Time Elapsed: 0.10315108299255371
#
# For User: 0x7a0C9037fB4E51dd10a921E1eA8AAee07862F644
# From Block: 19060961
# Fetching Repay events..
# Fetching complete.
# Time Elapsed: 0.10478591918945312
#
# For User: 0x7a0C9037fB4E51dd10a921E1eA8AAee07862F644
# From Block: 19060961
# Fetching FlashLoan events..
# Fetching complete.
# Time Elapsed: 1.468942642211914
#
# For User: 0xb5bFb68b2F40D211338bD5955E2733b9990ECDC9
# From Block: 19171823
# Fetching Withdraw events..
# Fetching complete.
# Time Elapsed: 0.0778191089630127
#
# For User: 0xb5bFb68b2F40D211338bD5955E2733b9990ECDC9
# From Block: 19171823
# Fetching Borrow events..
# Fetching complete.
# Time Elapsed: 0.09004330635070801
#
# For User: 0xb5bFb68b2F40D211338bD5955E2733b9990ECDC9
# From Block: 19171823
# Fetching Repay events..
# Fetching complete.
# Time Elapsed: 0.06667661666870117
#
# For User: 0xb5bFb68b2F40D211338bD5955E2733b9990ECDC9
# From Block: 19171823
# Fetching FlashLoan events..
# Fetching complete.
# Time Elapsed: 1.028057336807251
#
# For User: 0x65736A137cD4629454bB0226704dEec0AEF5adEd
# From Block: 17938398
# Fetching Withdraw events......
# Fetching complete.
# Time Elapsed: 0.3576018810272217
#
# For User: 0x65736A137cD4629454bB0226704dEec0AEF5adEd
# From Block: 17938398
# Fetching Borrow events......
# Fetching complete.
# Time Elapsed: 0.4681284427642822
#
# For User: 0x65736A137cD4629454bB0226704dEec0AEF5adEd
# From Block: 17938398
# Fetching Repay events......
# Fetching complete.
# Time Elapsed: 0.30364370346069336
#
# For User: 0x65736A137cD4629454bB0226704dEec0AEF5adEd
# From Block: 17938398
# Fetching FlashLoan events......
# Fetching complete.
# Time Elapsed: 6.09154486656189
#
# For User: 0xd04146CEd16190049e7Cf92fc8B7801584cA911f
# From Block: 19088417
# Fetching Withdraw events..
# Fetching complete.
# Time Elapsed: 0.0726158618927002
#
# For User: 0xd04146CEd16190049e7Cf92fc8B7801584cA911f
# From Block: 19088417
# Fetching Borrow events..
# Fetching complete.
# Time Elapsed: 0.10718274116516113
#
# For User: 0xd04146CEd16190049e7Cf92fc8B7801584cA911f
# From Block: 19088417
# Fetching Repay events..
# Fetching complete.
# Time Elapsed: 0.08836960792541504
#
# For User: 0xd04146CEd16190049e7Cf92fc8B7801584cA911f
# From Block: 19088417
# Fetching FlashLoan events..
# Fetching complete.
# Time Elapsed: 1.4270901679992676
#
# For User: 0xD5730830CFfd0b36B2046D6cB0B49734Ed90F560
# From Block: 19178555
# Fetching Withdraw events..
# Fetching complete.
# Time Elapsed: 0.10603761672973633
#
# For User: 0xD5730830CFfd0b36B2046D6cB0B49734Ed90F560
# From Block: 19178555
# Fetching Borrow events..
# Fetching complete.
# Time Elapsed: 0.08351325988769531
#
# For User: 0xD5730830CFfd0b36B2046D6cB0B49734Ed90F560
# From Block: 19178555
# Fetching Repay events..
# Fetching complete.
# Time Elapsed: 0.08477163314819336
#
# For User: 0xD5730830CFfd0b36B2046D6cB0B49734Ed90F560
# From Block: 19178555
# Fetching FlashLoan events..
# Fetching complete.
# Time Elapsed: 1.135554313659668
#
# For User: 0xdE13a331adF3B9b6F32017BC63dFf2f61A926a5a
# From Block: 16725591
# Fetching Withdraw events...........
# Fetching complete.
# Time Elapsed: 0.44571352005004883
#
# For User: 0xdE13a331adF3B9b6F32017BC63dFf2f61A926a5a
# From Block: 16725591
# Fetching Borrow events...........
# Fetching complete.
# Time Elapsed: 0.634077787399292
#
# For User: 0xdE13a331adF3B9b6F32017BC63dFf2f61A926a5a
# From Block: 16725591
# Fetching Repay events...........
# Fetching complete.
# Time Elapsed: 0.5311217308044434
#
# For User: 0xdE13a331adF3B9b6F32017BC63dFf2f61A926a5a
# From Block: 16725591
# Fetching FlashLoan events...........
# Fetching complete.
# Time Elapsed: 7.982879400253296
#
# For User: 0xe714428147AFAf35651C4716fb0a43C6ab089150
# From Block: 18734946
# Fetching Withdraw events...
# Fetching complete.
# Time Elapsed: 0.1609938144683838
#
# For User: 0xe714428147AFAf35651C4716fb0a43C6ab089150
# From Block: 18734946
# Fetching Borrow events...
# Fetching complete.
# Time Elapsed: 0.16047215461730957
#
# For User: 0xe714428147AFAf35651C4716fb0a43C6ab089150
# From Block: 18734946
# Fetching Repay events...
# Fetching complete.
# Time Elapsed: 0.4763669967651367
#
# For User: 0xe714428147AFAf35651C4716fb0a43C6ab089150
# From Block: 18734946
# Fetching FlashLoan events...
# Fetching complete.
# Time Elapsed: 3.233161687850952
#
# For User: 0x660Ec6b32C58f682e5d5C619758440e1357bD58C
# From Block: 18879342
# Fetching Withdraw events...
# Fetching complete.
# Time Elapsed: 0.18893003463745117
# For User: 0x660Ec6b32C58f682e5d5C619758440e1357bD58C
# From Block: 18879342
# Fetching Borrow events...
# Fetching complete.
# Time Elapsed: 0.2071225643157959
#
# For User: 0x660Ec6b32C58f682e5d5C619758440e1357bD58C
# From Block: 18879342
# Fetching Repay events...
# Fetching complete.
# Time Elapsed: 0.16970014572143555
#
# For User: 0x660Ec6b32C58f682e5d5C619758440e1357bD58C
# From Block: 18879342
# Fetching FlashLoan events...
# Fetching complete.
# Time Elapsed: 2.5115721225738525
#
# For User: 0xB58EBb9e37EBdd66eDF76499B6D4044175bA0484
# From Block: 19192598
# Fetching Withdraw events.
# Fetching complete.
# Time Elapsed: 0.04250025749206543
#
# For User: 0xB58EBb9e37EBdd66eDF76499B6D4044175bA0484
# From Block: 19192598
# Fetching Borrow events.
# Fetching complete.
# Time Elapsed: 0.03683781623840332
#
# For User: 0xB58EBb9e37EBdd66eDF76499B6D4044175bA0484
# From Block: 19192598
# Fetching Repay events.
# Fetching complete.
# Time Elapsed: 0.05235576629638672
#
# For User: 0xB58EBb9e37EBdd66eDF76499B6D4044175bA0484
# From Block: 19192598
# Fetching FlashLoan events.
# Fetching complete.
# Time Elapsed: 0.9497280120849609
#
# For User: 0xF23d31c67dF926D18995FcC9298bdf39a9A1253B
# From Block: 19200760
# Fetching Withdraw events.
# Fetching complete.
# Time Elapsed: 0.03875851631164551
#
# For User: 0xF23d31c67dF926D18995FcC9298bdf39a9A1253B
# From Block: 19200760
# Fetching Borrow events.
# Fetching complete.
# Time Elapsed: 0.03789353370666504
#
# For User: 0xF23d31c67dF926D18995FcC9298bdf39a9A1253B
# From Block: 19200760
# Fetching Repay events.
# Fetching complete.
# Time Elapsed: 0.03997159004211426
#
# For User: 0xF23d31c67dF926D18995FcC9298bdf39a9A1253B
# From Block: 19200760
# Fetching FlashLoan events.
# Fetching complete.
# Time Elapsed: 1.0322678089141846
#
# For User: 0xaB60e22017df361fC490AAb971cEeAF905D1b46d
# From Block: 19201960
# Fetching Withdraw events.
# Fetching complete.
# Time Elapsed: 0.033820390701293945
#
# For User: 0xaB60e22017df361fC490AAb971cEeAF905D1b46d
# From Block: 19201960
# Fetching Borrow events.
# Fetching complete.
# Time Elapsed: 0.07295370101928711
#
# For User: 0xaB60e22017df361fC490AAb971cEeAF905D1b46d
# From Block: 19201960
# Fetching Repay events.
# Fetching complete.
# Time Elapsed: 0.07896113395690918
#
# For User: 0xaB60e22017df361fC490AAb971cEeAF905D1b46d
# From Block: 19201960
# Fetching FlashLoan events.
# Fetching complete.
# Time Elapsed: 0.9506661891937256
#
# For User: 0xB3e349347384df88c903d888dB457cf4945EB4bd
# From Block: 19203555
# Fetching Withdraw events.
# Fetching complete.
# Time Elapsed: 0.04662156105041504
#
# For User: 0xB3e349347384df88c903d888dB457cf4945EB4bd
# From Block: 19203555
# Fetching Borrow events.
# Fetching complete.
# Time Elapsed: 0.040929317474365234
#
# For User: 0xB3e349347384df88c903d888dB457cf4945EB4bd
# From Block: 19203555
# Fetching Repay events.
# Fetching complete.
# Time Elapsed: 0.041022300720214844
#
# For User: 0xB3e349347384df88c903d888dB457cf4945EB4bd
# From Block: 19203555
# Fetching FlashLoan events.
# Fetching complete.
# Time Elapsed: 0.9208500385284424
#
# For User: 0xDCE7d721aCf944CeE5B8A9A810CcF336CF9c429A
# From Block: 19207213
# Fetching Withdraw events.
# Fetching complete.
# Time Elapsed: 0.03307962417602539
#
# For User: 0xDCE7d721aCf944CeE5B8A9A810CcF336CF9c429A
# From Block: 19207213
# Fetching Borrow events.
# Fetching complete.
# Time Elapsed: 0.11666607856750488
#
# For User: 0xDCE7d721aCf944CeE5B8A9A810CcF336CF9c429A
# From Block: 19207213
# Fetching Repay events.
# Fetching complete.
# Time Elapsed: 0.05402708053588867
#
# For User: 0xDCE7d721aCf944CeE5B8A9A810CcF336CF9c429A
# From Block: 19207213
# Fetching FlashLoan events.
# Fetching complete.
# Time Elapsed: 0.9162123203277588
#
# For User: 0x2d9B182d340A9189457e83d6034cca98Fc81cc6a
# From Block: 18259024
# Fetching Withdraw events.....
# Fetching complete.
# Time Elapsed: 0.2640407085418701
#
# For User: 0x2d9B182d340A9189457e83d6034cca98Fc81cc6a
# From Block: 18259024
# Fetching Borrow events.....
# Fetching complete.
# Time Elapsed: 0.3038303852081299
#
# For User: 0x2d9B182d340A9189457e83d6034cca98Fc81cc6a
# From Block: 18259024
# Fetching Repay events.....
# Fetching complete.
# Time Elapsed: 0.31408143043518066
#
# For User: 0x2d9B182d340A9189457e83d6034cca98Fc81cc6a
# From Block: 18259024
# Fetching FlashLoan events.....
# Fetching complete.
# Time Elapsed: 5.434018850326538
#
# For User: 0x03D630d683BcB93608722EC3878f310905e54865
# From Block: 19211350
# Fetching Withdraw events.
# Fetching complete.
# Time Elapsed: 0.09339380264282227
#
# For User: 0x03D630d683BcB93608722EC3878f310905e54865
# From Block: 19211350
# Fetching Borrow events.
# Fetching complete.
# Time Elapsed: 0.03596234321594238
#
# For User: 0x03D630d683BcB93608722EC3878f310905e54865
# From Block: 19211350
# Fetching Repay events.
# Fetching complete.
# Time Elapsed: 0.11727714538574219
#
# For User: 0x03D630d683BcB93608722EC3878f310905e54865
# From Block: 19211350
# Fetching FlashLoan events.
# Fetching complete.
# Time Elapsed: 0.9193933010101318
#
# For User: 0x35451b05E053B826538B03ad20F2eE5d76dB5Cea
# From Block: 16640152
# Fetching Withdraw events............
# Fetching complete.
# Time Elapsed: 0.6891367435455322
#
# For User: 0x35451b05E053B826538B03ad20F2eE5d76dB5Cea
# From Block: 16640152
# Fetching Borrow events............
# Fetching complete.
# Time Elapsed: 0.8406491279602051
#
# For User: 0x35451b05E053B826538B03ad20F2eE5d76dB5Cea
# From Block: 16640152
# Fetching Repay events............
# Fetching complete.
# Time Elapsed: 0.6035046577453613
#
# For User: 0x35451b05E053B826538B03ad20F2eE5d76dB5Cea
# From Block: 16640152
# Fetching FlashLoan events............
# Fetching complete.
# Time Elapsed: 8.137486934661865
#
# For User: 0x7A37Aff5d489B55E2787762Be2585ce34cFcBfe0
# From Block: 19219159
# Fetching Withdraw events.
# Fetching complete.
# Time Elapsed: 0.04898238182067871
#
# For User: 0x7A37Aff5d489B55E2787762Be2585ce34cFcBfe0
# From Block: 19219159
# Fetching Borrow events.
# Fetching complete.
# Time Elapsed: 0.04390144348144531
#
# For User: 0x7A37Aff5d489B55E2787762Be2585ce34cFcBfe0
# From Block: 19219159
# Fetching Repay events.
# Fetching complete.
# Time Elapsed: 0.04448342323303223
#
# For User: 0x7A37Aff5d489B55E2787762Be2585ce34cFcBfe0
# From Block: 19219159
# Fetching FlashLoan events.
# Fetching complete.
# Time Elapsed: 0.8834259510040283
#
# For User: 0xf51fA083336797D6E5f083e5a73208F3e185A8b9
# From Block: 19222599
# Fetching Withdraw events.
# Fetching complete.
# Time Elapsed: 0.03787946701049805
#
# For User: 0xf51fA083336797D6E5f083e5a73208F3e185A8b9
# From Block: 19222599
# Fetching Borrow events.
# Fetching complete.
# Time Elapsed: 0.05420517921447754
#
# For User: 0xf51fA083336797D6E5f083e5a73208F3e185A8b9
# From Block: 19222599
# Fetching Repay events.
# Fetching complete.
# Time Elapsed: 0.06720638275146484
#
# For User: 0xf51fA083336797D6E5f083e5a73208F3e185A8b9
# From Block: 19222599
# Fetching FlashLoan events.
# Fetching complete.
# Time Elapsed: 0.8504157066345215
#
# For User: 0x28AEdA0cd55D04C69a15506299Dc3d124cf210E1
# From Block: 17229167
# Fetching Withdraw events.........
# Fetching complete.
# Time Elapsed: 0.5804662704467773
#
# For User: 0x28AEdA0cd55D04C69a15506299Dc3d124cf210E1
# From Block: 17229167
# Fetching Borrow events.........
# Fetching complete.
# Time Elapsed: 0.4198276996612549
#
# For User: 0x28AEdA0cd55D04C69a15506299Dc3d124cf210E1
# From Block: 17229167
# Fetching Repay events.........
# Fetching complete.
# Time Elapsed: 0.3934469223022461
#
# For User: 0x28AEdA0cd55D04C69a15506299Dc3d124cf210E1
# From Block: 17229167
# Fetching FlashLoan events.........
# Fetching complete.
# Time Elapsed: 7.3218724727630615
#
# For User: 0xe5bD9c9792E13278FfD391Fed86Cf435869b0154
# From Block: 18591523
# Fetching Withdraw events....
# Fetching complete.
# Time Elapsed: 0.1667616367340088
#
# For User: 0xe5bD9c9792E13278FfD391Fed86Cf435869b0154
# From Block: 18591523
# Fetching Borrow events....
# Fetching complete.
# Time Elapsed: 0.16468214988708496
#
# For User: 0xe5bD9c9792E13278FfD391Fed86Cf435869b0154
# From Block: 18591523
# Fetching Repay events....
# Fetching complete.
# Time Elapsed: 0.14542007446289062
#
# For User: 0xe5bD9c9792E13278FfD391Fed86Cf435869b0154
# From Block: 18591523
# Fetching FlashLoan events....
# Fetching complete.
# Time Elapsed: 4.67060112953186
#
# For User: 0x0dCf166dDaF37C44A55F868A52B63d3Be1D51669
# From Block: 19224015
# Fetching Withdraw events.
# Fetching complete.
# Time Elapsed: 0.04101705551147461
#
# For User: 0x0dCf166dDaF37C44A55F868A52B63d3Be1D51669
# From Block: 19224015
# Fetching Borrow events.
# Fetching complete.
# Time Elapsed: 0.05886554718017578
# For User: 0x0dCf166dDaF37C44A55F868A52B63d3Be1D51669
# From Block: 19224015
# Fetching Repay events.
# Fetching complete.
# Time Elapsed: 0.04227590560913086
#
# For User: 0x0dCf166dDaF37C44A55F868A52B63d3Be1D51669
# From Block: 19224015
# Fetching FlashLoan events.
# Fetching complete.
# Time Elapsed: 0.9343211650848389
#
# For User: 0xB2df2d124cC5a4C9E3eaeB9719CE2DCEC88e9194
# From Block: 18089678
# Fetching Withdraw events......
# Fetching complete.
# Time Elapsed: 0.26015233993530273
#
# For User: 0xB2df2d124cC5a4C9E3eaeB9719CE2DCEC88e9194
# From Block: 18089678
# Fetching Borrow events......
# Fetching complete.
# Time Elapsed: 0.265627384185791
#
# For User: 0xB2df2d124cC5a4C9E3eaeB9719CE2DCEC88e9194
# From Block: 18089678
# Fetching Repay events......
# Fetching complete.
# Time Elapsed: 0.2226884365081787
#
# For User: 0xB2df2d124cC5a4C9E3eaeB9719CE2DCEC88e9194
# From Block: 18089678
# Fetching FlashLoan events......
# Fetching complete.
# Time Elapsed: 6.303126096725464
#
# For User: 0x74B70c07d64D5d4EcbEA925EC66c2eA0D5B6a67f
# From Block: 19224544
# Fetching Withdraw events.
# Fetching complete.
# Time Elapsed: 0.04620218276977539
#
# For User: 0x74B70c07d64D5d4EcbEA925EC66c2eA0D5B6a67f
# From Block: 19224544
# Fetching Borrow events.
# Fetching complete.
# Time Elapsed: 0.06446599960327148
#
# For User: 0x74B70c07d64D5d4EcbEA925EC66c2eA0D5B6a67f
# From Block: 19224544
# Fetching Repay events.
# Fetching complete.
# Time Elapsed: 0.06128811836242676
#
# For User: 0x74B70c07d64D5d4EcbEA925EC66c2eA0D5B6a67f
# From Block: 19224544
# Fetching FlashLoan events.
# Fetching complete.
# Time Elapsed: 0.8853793144226074
#
# For User: 0x95d2bA09182101f577Fb21D080FD9Bc0D916011C
# From Block: 17893030
# Fetching Withdraw events.......
# Fetching complete.
# Time Elapsed: 0.3373079299926758
#
# For User: 0x95d2bA09182101f577Fb21D080FD9Bc0D916011C
# From Block: 17893030
# Fetching Borrow events.......
# Fetching complete.
# Time Elapsed: 0.3138446807861328
#
# For User: 0x95d2bA09182101f577Fb21D080FD9Bc0D916011C
# From Block: 17893030
# Fetching Repay events.......
# Fetching complete.
# Time Elapsed: 0.36294031143188477
#
# For User: 0x95d2bA09182101f577Fb21D080FD9Bc0D916011C
# From Block: 17893030
# Fetching FlashLoan events.......
# Fetching complete.
# Time Elapsed: 6.293642520904541
#
# For User: 0x98AB3fAAa485882C0552C0a152B7ca1e9770cAC4
# From Block: 19225831
# Fetching Withdraw events.
# Fetching complete.
# Time Elapsed: 0.05396604537963867
#
# For User: 0x98AB3fAAa485882C0552C0a152B7ca1e9770cAC4
# From Block: 19225831
# Fetching Borrow events.
# Fetching complete.
# Time Elapsed: 0.05272531509399414
#
# For User: 0x98AB3fAAa485882C0552C0a152B7ca1e9770cAC4
# From Block: 19225831
# Fetching Repay events.
# Fetching complete.
# Time Elapsed: 0.05174398422241211
#
# For User: 0x98AB3fAAa485882C0552C0a152B7ca1e9770cAC4
# From Block: 19225831
# Fetching FlashLoan events.
# Fetching complete.
# Time Elapsed: 0.8493969440460205
#
# For User: 0x1980475c3a279935Ca611c9A41f17974ebC2e050
# From Block: 19226594
# Fetching Withdraw events.
# Fetching complete.
# Time Elapsed: 0.042368412017822266
#
# For User: 0x1980475c3a279935Ca611c9A41f17974ebC2e050
# From Block: 19226594
# Fetching Borrow events.
# Fetching complete.
# Time Elapsed: 0.0882561206817627
#
# For User: 0x1980475c3a279935Ca611c9A41f17974ebC2e050
# From Block: 19226594
# Fetching Repay events.
# Fetching complete.
# Time Elapsed: 0.09319019317626953
#
# For User: 0x1980475c3a279935Ca611c9A41f17974ebC2e050
# From Block: 19226594
# Fetching FlashLoan events.
# Fetching complete.
# Time Elapsed: 0.8734557628631592
#
# For User: 0xfB889B8A33b1A5e0C46c279b6848ffEfe2BA75C7
# From Block: 19227438
# Fetching Withdraw events.
# Fetching complete.
# Time Elapsed: 0.049091339111328125
#
# For User: 0xfB889B8A33b1A5e0C46c279b6848ffEfe2BA75C7
# From Block: 19227438
# Fetching Borrow events.
# Fetching complete.
# Time Elapsed: 0.041855812072753906
#
# For User: 0xfB889B8A33b1A5e0C46c279b6848ffEfe2BA75C7
# From Block: 19227438
# Fetching Repay events.
# Fetching complete.
# Time Elapsed: 0.03210949897766113
#
# For User: 0xfB889B8A33b1A5e0C46c279b6848ffEfe2BA75C7
# From Block: 19227438
# Fetching FlashLoan events.
# Fetching complete.
# Time Elapsed: 0.8960261344909668
#
# For User: 0x0403F4292c0814b947b8b35273B38F4609d272d5
# From Block: 18464010
# Fetching Withdraw events....
# Fetching complete.
# Time Elapsed: 0.16044068336486816
#
# For User: 0x0403F4292c0814b947b8b35273B38F4609d272d5
# From Block: 18464010
# Fetching Borrow events....
# Fetching complete.
# Time Elapsed: 0.20732355117797852
#
# For User: 0x0403F4292c0814b947b8b35273B38F4609d272d5
# From Block: 18464010
# Fetching Repay events....
# Fetching complete.
# Time Elapsed: 0.19367122650146484
#
# For User: 0x0403F4292c0814b947b8b35273B38F4609d272d5
# From Block: 18464010
# Fetching FlashLoan events....
# Fetching complete.
# Time Elapsed: 5.119852781295776
#
# For User: 0x8fCe57C00d63265755Bbf6af45711f78838596E2
# From Block: 18281072
# Fetching Withdraw events.....
# Fetching complete.
# Time Elapsed: 0.23214364051818848
#
# For User: 0x8fCe57C00d63265755Bbf6af45711f78838596E2
# From Block: 18281072
# Fetching Borrow events.....
# Fetching complete.
# Time Elapsed: 0.4609978199005127
#
# For User: 0x8fCe57C00d63265755Bbf6af45711f78838596E2
# From Block: 18281072
# Fetching Repay events.....
# Fetching complete.
# Time Elapsed: 0.22497129440307617
#
# For User: 0x8fCe57C00d63265755Bbf6af45711f78838596E2
# From Block: 18281072
# Fetching FlashLoan events.....
# Fetching complete.
# Time Elapsed: 6.043287038803101
#
# For User: 0x412B47f4084F17f08a43182e8aB7E8Cc17e8D20b
# From Block: 19231992
# Fetching Withdraw events.
# Fetching complete.
# Time Elapsed: 0.03986239433288574
#
# For User: 0x412B47f4084F17f08a43182e8aB7E8Cc17e8D20b
# From Block: 19231992
# Fetching Borrow events.
# Fetching complete.
# Time Elapsed: 0.0730142593383789
#
# For User: 0x412B47f4084F17f08a43182e8aB7E8Cc17e8D20b
# From Block: 19231992
# Fetching Repay events.
# Fetching complete.
# Time Elapsed: 0.0489344596862793
#
# For User: 0x412B47f4084F17f08a43182e8aB7E8Cc17e8D20b
# From Block: 19231992
# Fetching FlashLoan events.
# Fetching complete.
# Time Elapsed: 1.0386366844177246
#
# For User: 0xF899FE47aa2C716615Fb1AdFf52361f309fDf4b7
# From Block: 19046874
# Fetching Withdraw events..
# Fetching complete.
# Time Elapsed: 0.09608030319213867
#
# For User: 0xF899FE47aa2C716615Fb1AdFf52361f309fDf4b7
# From Block: 19046874
# Fetching Borrow events..
# Fetching complete.
# Time Elapsed: 0.0903329849243164
#
# For User: 0xF899FE47aa2C716615Fb1AdFf52361f309fDf4b7
# From Block: 19046874
# Fetching Repay events..
# Fetching complete.
# Time Elapsed: 0.07103872299194336
#
# For User: 0xF899FE47aa2C716615Fb1AdFf52361f309fDf4b7
# From Block: 19046874
# Fetching FlashLoan events..
# Fetching complete.
# Time Elapsed: 1.666883945465088
#
# For User: 0xA3dFB42724734D74d1B66f6F12a4AfA5D7D38DF2
# From Block: 19233460
# Fetching Withdraw events.
# Fetching complete.
# Time Elapsed: 0.0416109561920166
#
# For User: 0xA3dFB42724734D74d1B66f6F12a4AfA5D7D38DF2
# From Block: 19233460
# Fetching Borrow events.
# Fetching complete.
# Time Elapsed: 0.049922943115234375
#
# For User: 0xA3dFB42724734D74d1B66f6F12a4AfA5D7D38DF2
# From Block: 19233460
# Fetching Repay events.
# Fetching complete.
# Time Elapsed: 0.04143524169921875
#
# For User: 0xA3dFB42724734D74d1B66f6F12a4AfA5D7D38DF2
# From Block: 19233460
# Fetching FlashLoan events.
# Fetching complete.
# Time Elapsed: 0.8222227096557617
#
# For User: 0xD3e842A1D04F9Edaa328cca8874C8896F0044CfB
# From Block: 19244335
# Fetching Withdraw events.
# Fetching complete.
# Time Elapsed: 0.06356358528137207
#
# For User: 0xD3e842A1D04F9Edaa328cca8874C8896F0044CfB
# From Block: 19244335
# Fetching Borrow events.
# Fetching complete.
# Time Elapsed: 0.05987286567687988
#
# For User: 0xD3e842A1D04F9Edaa328cca8874C8896F0044CfB
# From Block: 19244335
# Fetching Repay events.
# Fetching complete.
# Time Elapsed: 0.04824423789978027
#
# For User: 0xD3e842A1D04F9Edaa328cca8874C8896F0044CfB
# From Block: 19244335
# Fetching FlashLoan events.
# Fetching complete.
# Time Elapsed: 0.8741970062255859
#
# For User: 0x6D417A58cA6BDBc7C52AC98B9Ce74381c4D0c5E5
# From Block: 19247666
# Fetching Withdraw events.
# Fetching complete.
# Time Elapsed: 0.04540443420410156
#
# For User: 0x6D417A58cA6BDBc7C52AC98B9Ce74381c4D0c5E5
# From Block: 19247666
# Fetching Borrow events.
# Fetching complete.
# Time Elapsed: 0.0421748161315918
#
# For User: 0x6D417A58cA6BDBc7C52AC98B9Ce74381c4D0c5E5
# From Block: 19247666
# Fetching Repay events.
# Fetching complete.
# Time Elapsed: 0.04395699501037598
#
# For User: 0x6D417A58cA6BDBc7C52AC98B9Ce74381c4D0c5E5
# From Block: 19247666
# Fetching FlashLoan events.
# Fetching complete.
# Time Elapsed: 0.8828656673431396
#
# For User: 0xf5dB697A5aD188FDDc9258FFF2206253932A467D
# From Block: 18783909
# Fetching Withdraw events...
# Fetching complete.
# Time Elapsed: 0.13272309303283691
#
# For User: 0xf5dB697A5aD188FDDc9258FFF2206253932A467D
# From Block: 18783909
# Fetching Borrow events...
# Fetching complete.
# Time Elapsed: 0.13799619674682617
#
# For User: 0xf5dB697A5aD188FDDc9258FFF2206253932A467D
# From Block: 18783909
# Fetching Repay events...
# Fetching complete.
# Time Elapsed: 0.14848589897155762
#
# For User: 0xf5dB697A5aD188FDDc9258FFF2206253932A467D
# From Block: 18783909
# Fetching FlashLoan events...
# Fetching complete.
# Time Elapsed: 3.1475675106048584
#
# For User: 0x551C5aAdB287D086B47DaBd0cf4d8e83965e79B5
# From Block: 18469732
# Fetching Withdraw events....
# Fetching complete.
# Time Elapsed: 0.16596055030822754
#
# For User: 0x551C5aAdB287D086B47DaBd0cf4d8e83965e79B5
# From Block: 18469732
# Fetching Borrow events....
# Fetching complete.
# Time Elapsed: 0.21140766143798828
#
# For User: 0x551C5aAdB287D086B47DaBd0cf4d8e83965e79B5
# From Block: 18469732
# Fetching Repay events....
# Fetching complete.
# Time Elapsed: 0.22718548774719238
#
# For User: 0x551C5aAdB287D086B47DaBd0cf4d8e83965e79B5
# From Block: 18469732
# Fetching FlashLoan events....
# Fetching complete.
# Time Elapsed: 4.568346977233887
#
# For User: 0x0AcB169093665dfdd69Af8EF1314499fCE7e0EDD
# From Block: 19260408
# Fetching Withdraw events.
# Fetching complete.
# Time Elapsed: 0.06537985801696777
#
# For User: 0x0AcB169093665dfdd69Af8EF1314499fCE7e0EDD
# From Block: 19260408
# Fetching Borrow events.
# Fetching complete.
# Time Elapsed: 0.05991864204406738
#
# For User: 0x0AcB169093665dfdd69Af8EF1314499fCE7e0EDD
# From Block: 19260408
# Fetching Repay events.
# Fetching complete.
# Time Elapsed: 0.0437312126159668
#
# For User: 0x0AcB169093665dfdd69Af8EF1314499fCE7e0EDD
# From Block: 19260408
# Fetching FlashLoan events.
# Fetching complete.
# Time Elapsed: 0.7364702224731445
#
# For User: 0xBb7ec7244d3C6E60d16AfF6C4ce782e115df5480
# From Block: 19279226
# Fetching Withdraw events.
# Fetching complete.
# Time Elapsed: 0.036478281021118164
#
# For User: 0xBb7ec7244d3C6E60d16AfF6C4ce782e115df5480
# From Block: 19279226
# Fetching Borrow events.
# Fetching complete.
# Time Elapsed: 0.04948902130126953
#
# For User: 0xBb7ec7244d3C6E60d16AfF6C4ce782e115df5480
# From Block: 19279226
# Fetching Repay events.
# Fetching complete.
# Time Elapsed: 0.05216360092163086
#
# For User: 0xBb7ec7244d3C6E60d16AfF6C4ce782e115df5480
# From Block: 19279226
# Fetching FlashLoan events.
# Fetching complete.
# Time Elapsed: 0.7258813381195068
#
# For User: 0x02cE0DDcBf374960FF78A8a42603ec8aA01baA0f
# From Block: 19300225
# Fetching Withdraw events.
# Fetching complete.
# Time Elapsed: 0.10912680625915527
#
# For User: 0x02cE0DDcBf374960FF78A8a42603ec8aA01baA0f
# From Block: 19300225
# Fetching Borrow events.
# Fetching complete.
# Time Elapsed: 0.052817344665527344
#
# For User: 0x02cE0DDcBf374960FF78A8a42603ec8aA01baA0f
# From Block: 19300225
# Fetching Repay events.
# Fetching complete.
# Time Elapsed: 0.04700803756713867
#
# For User: 0x02cE0DDcBf374960FF78A8a42603ec8aA01baA0f
# From Block: 19300225
# Fetching FlashLoan events.
# Fetching complete.
# Time Elapsed: 0.6261410713195801
#
# For User: 0xaf686d9F2B46C8492b0E4CD0a92352e7e72Ccb97
# From Block: 18979283
# Fetching Withdraw events..
# Fetching complete.
# Time Elapsed: 0.11494302749633789
#
# For User: 0xaf686d9F2B46C8492b0E4CD0a92352e7e72Ccb97
# From Block: 18979283
# Fetching Borrow events..
# Fetching complete.
# Time Elapsed: 0.17310428619384766
#
# For User: 0xaf686d9F2B46C8492b0E4CD0a92352e7e72Ccb97
# From Block: 18979283
# Fetching Repay events..
# Fetching complete.
# Time Elapsed: 0.14321279525756836
#
# For User: 0xaf686d9F2B46C8492b0E4CD0a92352e7e72Ccb97
# From Block: 18979283
# Fetching FlashLoan events..
# Fetching complete.
# Time Elapsed: 1.8590457439422607
#
# For User: 0xa7F3C74f0255796Fd5D3DDCf88db769f7a6bf46a
# From Block: 19080021
# Fetching Withdraw events..
# Fetching complete.
# Time Elapsed: 0.07439756393432617
#
# For User: 0xa7F3C74f0255796Fd5D3DDCf88db769f7a6bf46a
# From Block: 19080021
# Fetching Borrow events..
# Fetching complete.
# Time Elapsed: 0.11877155303955078
#
# For User: 0xa7F3C74f0255796Fd5D3DDCf88db769f7a6bf46a
# From Block: 19080021
# Fetching Repay events..
# Fetching complete.
# Time Elapsed: 0.07450175285339355
#
# For User: 0xa7F3C74f0255796Fd5D3DDCf88db769f7a6bf46a
# From Block: 19080021
# Fetching FlashLoan events..
# Fetching complete.
# Time Elapsed: 1.3704864978790283
#
# For User: 0xad1A74a31b00ED0403Bb7d8B11130E30Ae15853C
# From Block: 19304653
# Fetching Withdraw events.
# Fetching complete.
# Time Elapsed: 0.03935956954956055
#
# For User: 0xad1A74a31b00ED0403Bb7d8B11130E30Ae15853C
# From Block: 19304653
# Fetching Borrow events.
# Fetching complete.
# Time Elapsed: 0.05513739585876465
#
# For User: 0xad1A74a31b00ED0403Bb7d8B11130E30Ae15853C
# From Block: 19304653
# Fetching Repay events.
# Fetching complete.
# Time Elapsed: 0.04443693161010742
#
# For User: 0xad1A74a31b00ED0403Bb7d8B11130E30Ae15853C
# From Block: 19304653
# Fetching FlashLoan events.
# Fetching complete.
# Time Elapsed: 0.6400167942047119

# %%
all_dfs = []

for key, dfs_list in interaction_list.items():
    # Concatenate all DataFrames in the list for the current wallet address
    combined_df = pd.concat(dfs_list, ignore_index=True)
    all_dfs.append(combined_df)

# Concatenate all combined DataFrames into one
final_df = pd.concat(all_dfs, ignore_index=True)
final_df
# Out:
#       Event Type                                   Transaction Hash  \
# 0         Borrow  0x922675f27fd9a372bedb978dcdffd27d60631667b9f5...
# 1         Borrow  0xa9b6bdde432cce8a7877e943161b3c3fc302691b0bdc...
# 2          Repay  0x7502a548129b945b074fbc3143e693dcc84509342d05...
# 3          Repay  0xc5532707ea840d9fb1e8acad45f8cb3d31e25839b216...
# 4         Borrow  0x53237b478e01073f714423746b4947b3fe3c70906f57...
# ...          ...                                                ...
# 13714   Withdraw  0x92765195b71326a11cc2917275a5b6ce03bbb04f836b...
# 13715     Borrow  0xf29a024f48cafc84aa26cb27010676d8bf46562c56d1...
# 13716     Borrow  0xd4dddbaf889488dd6f955b04c3df948988ae01772c16...
# 13717      Repay  0x5fefe317248cdd1dbd837f81db17e8f0b44930b5e5ae...
# 13718      Repay  0x1dc761047e05274021f5ae1bfe23d9d6430cdd557ec0...
#
#                                           Address  \
# 0      0x87870Bca3F3fD6335C3F4ce8392D69350B4fA4E2
# 1      0x87870Bca3F3fD6335C3F4ce8392D69350B4fA4E2
# 2      0x87870Bca3F3fD6335C3F4ce8392D69350B4fA4E2
# 3      0x87870Bca3F3fD6335C3F4ce8392D69350B4fA4E2
# 4      0x87870Bca3F3fD6335C3F4ce8392D69350B4fA4E2
# ...                                           ...
# 13714  0x87870Bca3F3fD6335C3F4ce8392D69350B4fA4E2
# 13715  0x87870Bca3F3fD6335C3F4ce8392D69350B4fA4E2
# 13716  0x87870Bca3F3fD6335C3F4ce8392D69350B4fA4E2
# 13717  0x87870Bca3F3fD6335C3F4ce8392D69350B4fA4E2
# 13718  0x87870Bca3F3fD6335C3F4ce8392D69350B4fA4E2
#
#                                               Block Hash  Block Number  \
# 0      0x395cf3cad6c726e6e7cefef81dab65c1ee9f0cff8c63...      19253214
# 1      0x0aebf5f1b8237ed5174836af0e81a9bb7b9d21151a5e...      19395873
# 2      0x6a5b9a35929e4c764697273b609e58045667ffd51902...      19194122
# 3      0x86cbfa0fcae8734577aa57710fb2d0b181dd9d438f7e...      19194127
# 4      0xc208dcc0d793e304440c7ac1e21f9bd39bf6479a3a25...      19223002
# ...                                                  ...           ...
# 13714  0x8a89fbec2c17524589c1678683d1c3c0525f674be43d...      19352043
# 13715  0x68e759b4c48ed73c06cc85bf294d5ad3d7cb83f5d19b...      19301585
# 13716  0xd5c1822d197346f6309ee693e8c89ccf3127e66b6419...      19080025
# 13717  0x27df8ea99c1db9df10d23a795ac325db5b7a51969bcc...      19228650
# 13718  0x2529870ba03d4e3b824ccf18a7bfe15a767d160f89ae...      19352072
#
#                                           Reserve  \
# 0      0xA0b86991c6218b36c1d19D4a2e9Eb0cE3606eB48
# 1      0xdAC17F958D2ee523a2206206994597C13D831ec7
# 2      0xdAC17F958D2ee523a2206206994597C13D831ec7
# 3      0xdAC17F958D2ee523a2206206994597C13D831ec7
# 4      0xA0b86991c6218b36c1d19D4a2e9Eb0cE3606eB48
# ...                                           ...
# 13714  0xae78736Cd615f374D3085123A210448E74Fc6393
# 13715  0xdAC17F958D2ee523a2206206994597C13D831ec7
# 13716  0xA0b86991c6218b36c1d19D4a2e9Eb0cE3606eB48
# 13717  0xA0b86991c6218b36c1d19D4a2e9Eb0cE3606eB48
# 13718  0xdAC17F958D2ee523a2206206994597C13D831ec7
#
#                                      On Behalf Of  \
# 0      0xc83894aC498289E54FBE523c0ABFcbac8CeB1CaB
# 1      0xc83894aC498289E54FBE523c0ABFcbac8CeB1CaB
# 2                                             NaN
# 3                                             NaN
# 4      0x1A415A3b77ED38B683Db945dc83F53ECda26F716
# ...                                           ...
# 13714                                         NaN
# 13715  0xa7F3C74f0255796Fd5D3DDCf88db769f7a6bf46a
# 13716  0xa7F3C74f0255796Fd5D3DDCf88db769f7a6bf46a
# 13717                                         NaN
# 13718                                         NaN
#
#                                              User                 Amount  \
# 0      0xc83894aC498289E54FBE523c0ABFcbac8CeB1CaB            50000000000
# 1      0xc83894aC498289E54FBE523c0ABFcbac8CeB1CaB           150000000000
# 2      0xc83894aC498289E54FBE523c0ABFcbac8CeB1CaB            15514000000
# 3      0xc83894aC498289E54FBE523c0ABFcbac8CeB1CaB           139623000000
# 4      0x1A415A3b77ED38B683Db945dc83F53ECda26F716            12900000000
# ...                                           ...                    ...
# 13714  0xa7F3C74f0255796Fd5D3DDCf88db769f7a6bf46a  201000000000000000000
# 13715  0xa7F3C74f0255796Fd5D3DDCf88db769f7a6bf46a           670000000000
# 13716  0xa7F3C74f0255796Fd5D3DDCf88db769f7a6bf46a           250000000000
# 13717  0xa7F3C74f0255796Fd5D3DDCf88db769f7a6bf46a           251108520091
# 13718  0xa7F3C74f0255796Fd5D3DDCf88db769f7a6bf46a           671590041404
#
#                        Borrow Rate  \
# 0       90557895041748529955456040
# 1      104111745662285810140385993
# 2                              NaN
# 3                              NaN
# 4      115909922884666592392623660
# ...                            ...
# 13714                          NaN
# 13715   59387665988109620450038412
# 13716   59622078712477660230987677
# 13717                          NaN
# 13718                          NaN
#
#                                           Repayer useAtokens  \
# 0                                             NaN        NaN
# 1                                             NaN        NaN
# 2      0xc83894aC498289E54FBE523c0ABFcbac8CeB1CaB      False
# 3      0xc83894aC498289E54FBE523c0ABFcbac8CeB1CaB      False
# 4                                             NaN        NaN
# ...                                           ...        ...
# 13714                                         NaN        NaN
# 13715                                         NaN        NaN
# 13716                                         NaN        NaN
# 13717  0xa7F3C74f0255796Fd5D3DDCf88db769f7a6bf46a      False
# 13718  0xa7F3C74f0255796Fd5D3DDCf88db769f7a6bf46a      False
#
#                                                To Target Asset Referral Code  \
# 0                                             NaN    NaN   NaN           NaN
# 1                                             NaN    NaN   NaN           NaN
# 2                                             NaN    NaN   NaN           NaN
# 3                                             NaN    NaN   NaN           NaN
# 4                                             NaN    NaN   NaN           NaN
# ...                                           ...    ...   ...           ...
# 13714  0xa7F3C74f0255796Fd5D3DDCf88db769f7a6bf46a    NaN   NaN           NaN
# 13715                                         NaN    NaN   NaN           NaN
# 13716                                         NaN    NaN   NaN           NaN
# 13717                                         NaN    NaN   NaN           NaN
# 13718                                         NaN    NaN   NaN           NaN
#
#       Initiator  Premium
# 0           NaN      NaN
# 1           NaN      NaN
# 2           NaN      NaN
# 3           NaN      NaN
# 4           NaN      NaN
# ...         ...      ...
# 13714       NaN      NaN
# 13715       NaN      NaN
# 13716       NaN      NaN
# 13717       NaN      NaN
# 13718       NaN      NaN
#
# [13719 rows x 18 columns]

# %%
final_df.to_csv('./transaction_data.csv', index=False)
