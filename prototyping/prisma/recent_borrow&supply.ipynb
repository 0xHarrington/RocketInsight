# %%
import pandas as pd
import json
from web3 import Web3
from datetime import datetime, timedelta
import time
import sys
import json
from collections import Counter

# Map token names to contract addresses
token_address_map = {
    'rETH': '0xae78736Cd615f374D3085123A210448E74Fc6393'
    # fill with rest
}

# Map market name to "Pool" contract address and abi filepath
contract_address_abi_map = {
    'AAVE': ('0x87870Bca3F3fD6335C3F4ce8392D69350B4fA4E2', './AAVE_Pool_ABI.json'),
    'COMPOUND': ('0xA17581A9E3356d9A858b789D68B4d866e593aE94', './Compound_ABI.json'),
    'PRISMA': (['0x0d6741f1A3A538F78009ca2e3a13F9cB1478B2d0', './Prisma_TroveManagerNew_ABI.json'], 
              ['0xe0e255FD5281bEc3bB8fa1569a20097D9064E445', './Prisma_TroveManagerOld_ABI.json'])
    # fill with rest
}

# Connect to ETH blockchain with infura API key
w3 = Web3(Web3.HTTPProvider('https://mainnet.infura.io/v3/7e4f5238262543919688a59d0fef4a1d'))

# %%
# Find block number closest to timestamp with binary search
def find_block_by_timestamp(target_timestamp):
    low, high = 0, w3.eth.block_number
    while low < high:
        mid = (low + high) // 2
        mid_block_timestamp = w3.eth.get_block(mid).timestamp
        if mid_block_timestamp < target_timestamp:
            low = mid+1
        else:
            high = mid
    return low


# Helper to convert block number to readable timestamp string
def get_block_timestamp(block_num):
    block = w3.eth.get_block(block_num)
    timestamp = block.timestamp
    
    return timestamp


# Lists transactions of supplying rETH to specified markets
def supply_transactions(market, timeframe = 30, token = 'rETH'):
    """
    Returns all "Supply" transactions for rETH from the specified markets over a given timeframe expressed as days.
        (Example: supply_transactions(AAVE, 90, rETH) returns all supply transactions for rETH on the AAVE market in the past 90 days
        
    Parameters:
    - markets (str): The lending and borrowing market from which to fetch data. Defaults to 'AAVE'.
    - timeframe (int): The number of days back from the current date to fetch data. Defaults to 90 days.
    - token (str): The token we want to see supply transactions for. Defaults to rETH
    
    Returns:
    pandas.DataFrame: A DataFrame where each row corresponds to a unique supply transaction with the following columns:
        - 'User (Wallet Address)': The address for the user who initiated the transaction
        - 'Amount (Wei)': The amount supplied expressed in Wei
        - 'Amount (rETH)': The amount supplied expressed in rETH
        - 'Timestamp': The timestamp in 'YYYY-MM-DD HH:MM:SS' format.
        - 'LogIndex': The log index
        - 'TransactionIndex': The transaction index
        - 'TransactionHash': The hash for the transaction
        - 'BlockHash': The hash for the block
        - 'BlockNumber': The block number
    
    """
    supply_list = []
    # Lookup token address
    token_address = token_address_map[token]
    
    # Get timestamp of timeframe provided
    current_time = datetime.now()
    start_time = current_time - timedelta(days=timeframe)
    st_timestamp = int(start_time.timestamp())
    
    # Find the block associated with our start_time timestamp
    st_block = find_block_by_timestamp(st_timestamp)
    
    # Make sure the requested market is supported
    if market in contract_address_abi_map.keys():
        # Set up contract address and ABI for each market
        contract_address, abi_filepath = contract_address_abi_map[market]
        
        if (market != 'PRISMA'):
            # Web3 setup
            with open(abi_filepath) as f:
                abi = json.load(f)
            
            smart_contract = w3.eth.contract(address=contract_address, abi=abi)
        else:
            smart_contract = []
            with open(contract_address[1]) as f:
                abi = json.load(f)
            smart_contract.append(w3.eth.contract(address=contract_address[0], abi=abi))
            with open(abi_filepath[1]) as f:
                abi = json.load(f)
            smart_contract.append(w3.eth.contract(address=abi_filepath[0], abi=abi))

        # Here we will need some sort of if/else or switching logic to process unique calls for each market
        # In the meantime, we simply check for the only supported market, 'AAVE'
        if market == 'AAVE':
            supplies = smart_contract.events.Supply().get_logs(fromBlock=st_block,
                                                       toBlock='latest',
                                                       argument_filters={'reserve': token_address})
            # Consider simplifying supply_list.. don't know what information future markets will return, 
            # ... Will most likely trim this down to: Reserve, User, Amount (in token, not Wei), Timestamp, and block number
            supply_list = [
                {
                'Reserve': event['args']['reserve'],
                'User (Wallet Address)': event['args']['user'],
                'Amount (Wei)': event['args']['amount'],
                'Amount (rETH)': event['args']['amount']/10**18,
                'Timestamp': get_block_timestamp(event['blockNumber']), # This particular line results in an aditional API call
                'LogIndex': event['logIndex'],
                'TransactionIndex': event['transactionIndex'],
                'TransactionHash': event['transactionHash'].hex(),
                'BlockHash': event['blockHash'].hex(),
                'BlockNumber': event['blockNumber']
                }
                for event in supplies
            ]
        elif market == 'COMPOUND':
            supplies = smart_contract.events.SupplyCollateral().get_logs(fromBlock=st_block,
                                                toBlock='latest',
                                                argument_filters={'asset': '0xae78736Cd615f374D3085123A210448E74Fc6393'})
            supply_list = [
                {
                'Reserve': event['args']['asset'],
                'User (Wallet Address)': event['args']['from'],
                'Amount (Wei)': event['args']['amount'],
                'Amount (rETH)': event['args']['amount']/10**18,
                'Timestamp': get_block_timestamp(event['blockNumber']), # This particular line results in an aditional API call
                'LogIndex': event['logIndex'],
                'TransactionIndex': event['transactionIndex'],
                'TransactionHash': event['transactionHash'].hex(),
                'BlockHash': event['blockHash'].hex(),
                'BlockNumber': event['blockNumber']
                }
                for event in supplies
            ]
        elif market == 'PRISMA':
            all_supplies = []
            for contract in smart_contract:
                supplies = contract.events.CollateralSent().get_logs(fromBlock=st_block,
                                                       toBlock='latest')
                supply_list = [
                    {
                    'Reserve': '0xae78736Cd615f374D3085123A210448E74Fc6393',
                    'User (Wallet Address)': event['args']['_to'],
                    'Amount (Wei)': event['args']['_amount'],
                    'Amount (rETH)': event['args']['_amount']/10**18,
                    'Timestamp': get_block_timestamp(event['blockNumber']), # This particular line results in an aditional API call
                    'LogIndex': event['logIndex'],
                    'TransactionIndex': event['transactionIndex'],
                    'TransactionHash': event['transactionHash'].hex(),
                    'BlockHash': event['blockHash'].hex(),
                    'BlockNumber': event['blockNumber']
                    }
                    for event in supplies
                ]
                all_supplies.extend(supply_list)
                
            supply_list = all_supplies
        else:
            print("UNSUPPORTED MARKET ENTERED")
            return
        
        # Push supply into dataframe
        recent_supplies = pd.DataFrame(supply_list)
        #recent_supplies['Timestamp'] = pd.to_datetime(recent_supplies[0]['Timestamp'])
        return recent_supplies
        
    # The market wasn't in our dictionary of supported markets
    else:
        print("UNSUPPORTED MARKET ENTERED")
        return []

"""
The above and below functions are extremely similar, the only difference being the API call they use, 
One function could have been used with some flow control and an additional parameter (User passes in "Borrow" or "Supply"
and the program runs accordingly); however, without knowing how future markets will behave, what their API calls will
exactly look like, and what they will return, it was decided to keep the two separate in case more complex logic is 
needed in handling either case specifically. 
"""


# Lists transactions of borrowing rETH to specified markets
def borrow_transactions(market, timeframe = 30, token = 'rETH'):
    """
    Returns all "Borrow" transactions for rETH from the specified markets over a given timeframe expressed as days.
        (Example: borrow_transactions(AAVE, 90, rETH) returns all borrow transactions for rETH on the AAVE market in the past 90 days
        
    Parameters:
    - markets (str): The lending and borrowing market from which to fetch data. Defaults to 'AAVE'.
    - timeframe (int): The number of days back from the current date to fetch data. Defaults to 90 days.
    - token (str): The token we want to see supply transactions for. Defaults to rETH
    
    Returns:
    pandas.DataFrame: A DataFrame where each row corresponds to a unique borrow transaction with the following columns:
        - 'User (Wallet Address)': The address for the user who initiated the transaction
        - 'Amount (Wei)': The amount supplied expressed in Wei
        - 'Amount (rETH)': The amount supplied expressed in rETH
        - 'Timestamp': The timestamp in 'YYYY-MM-DD HH:MM:SS' format.
        - 'LogIndex': The log index
        - 'TransactionIndex': The transaction index
        - 'TransactionHash': The hash for the transaction
        - 'BlockHash': The hash for the block
        - 'BlockNumber': The block number
    
    """
    # List for borrow_lists of all markets
    all_market_borrow_list = []
    
    # Lookup token address
    token_address = token_address_map[token]
    
    # Get timestamp of timeframe provided
    current_time = datetime.now()
    start_time = current_time - timedelta(days=timeframe)
    st_timestamp = int(start_time.timestamp())
    
    # Find the block associated with our start_time timestamp
    st_block = find_block_by_timestamp(st_timestamp)
    
    # Make sure the requested market is supported
    if market in contract_address_abi_map.keys():
        # Set up contract address and ABI for each market
        contract_address, abi_filepath = contract_address_abi_map[market]

        # Web3 setup
        with open(abi_filepath) as f:
            abi = json.load(f)

        smart_contract = w3.eth.contract(address=contract_address, abi=abi)

        # Here we will need some sort of if/else or switching logic to process unique calls for each market
        # In the meantime, we simply check for the only supported market, 'AAVE'
        if market == 'AAVE':
            borrows = smart_contract.events.Borrow().get_logs(fromBlock=st_block,
                                                       toBlock='latest',
                                                       argument_filters={'reserve': token_address})
            # Consider simplifying borrow_list.. don't know what information future markets will return, 
            # ... Will most likely trim this down to: Reserve, User, Amount (in token, not Wei), Timestamp, and block number
            borrow_list = [
                {
                    'Reserve': event['args']['reserve'],
                    'User (Wallet Address)': event['args']['user'],
                    'Amount (Wei)': event['args']['amount'],
                    'Amount (rETH)': event['args']['amount']/10**18,
                    'Timestamp': get_block_timestamp(event['blockNumber']), # This particular line results in an aditional API call
                    'LogIndex': event['logIndex'],
                    'TransactionIndex': event['transactionIndex'],
                    'TransactionHash': event['transactionHash'].hex(),
                    'BlockHash': event['blockHash'].hex(),
                    'BlockNumber': event['blockNumber']
                }
                for event in borrows
            ]
        elif market == 'COMPOUND':
            print("Compound currently doesn't support borrowing of rETH")
            return
        elif market == 'PRISMA':
            print("Prisma currently doesn't support borrowing of rETH")
            return
        else:
            print("FUTURE MARKETS HERE")
            return
        
        # Push borrows into dataframe
        recent_borrows = pd.DataFrame(borrow_list)
        #recent_supplies['Timestamp'] = pd.to_datetime(recent_supplies[0]['Timestamp'])
        return recent_borrows
    # The market wasn't in our dictionary of supported markets
    else:
        print("UNSUPPORTED MARKET ENTERED")
        return []

# %%
recent = supply_transactions('PRISMA')
recent
# Out:
# ['0x0d6741f1A3A538F78009ca2e3a13F9cB1478B2d0', './Prisma_TroveManagerNew_ABI.json'] ['0xe0e255FD5281bEc3bB8fa1569a20097D9064E445', './Prisma_TroveManagerOld_ABI.json']
#                                         Reserve  \
# 0    0xae78736Cd615f374D3085123A210448E74Fc6393
# 1    0xae78736Cd615f374D3085123A210448E74Fc6393
# 2    0xae78736Cd615f374D3085123A210448E74Fc6393
# 3    0xae78736Cd615f374D3085123A210448E74Fc6393
# 4    0xae78736Cd615f374D3085123A210448E74Fc6393
# ..                                          ...
# 109  0xae78736Cd615f374D3085123A210448E74Fc6393
# 110  0xae78736Cd615f374D3085123A210448E74Fc6393
# 111  0xae78736Cd615f374D3085123A210448E74Fc6393
# 112  0xae78736Cd615f374D3085123A210448E74Fc6393
# 113  0xae78736Cd615f374D3085123A210448E74Fc6393
#
#                           User (Wallet Address)           Amount (Wei)  \
# 0    0x731bA6d73718E86d6B12Fd373d648862de3f4056    2421000000000000000
# 1    0x192820CE84FA9eb457Fb228c386fE0ed22F7E33C  150000000000000000000
# 2    0x3B15CEc2d922Ab0Ef74688bcC1056461049f89CB   11078216393329209654
# 3    0x1fEC6F448Eb3ff479Ea9682F7eFf21A69762318f   34000000000000000000
# 4    0x51A125F89CBE0bFBFD62FeE8a750AAeC8fabC441   10497966470149292860
# ..                                          ...                    ...
# 109  0x5c15ceD59fD964fCFFF2d2F376b4a40b6D1Fce1c    2290936307831773000
# 110  0xEaa44e71a7723867e20fcc0a17045a5CfF621B8E    4549510035699037054
# 111  0x5c15ceD59fD964fCFFF2d2F376b4a40b6D1Fce1c    2741576764724075646
# 112  0x5c15ceD59fD964fCFFF2d2F376b4a40b6D1Fce1c    4000000000000000000
# 113  0x5c15ceD59fD964fCFFF2d2F376b4a40b6D1Fce1c   85704201770127604563
#
#      Amount (rETH)   Timestamp  LogIndex  TransactionIndex  \
# 0         2.421000  1711267139       245               117
# 1       150.000000  1711627067        37                 5
# 2        11.078216  1711628939       223               116
# 3        34.000000  1711636655       128                57
# 4        10.497966  1711640171       220               186
# ..             ...         ...       ...               ...
# 109       2.290936  1712501903       173                90
# 110       4.549510  1712604611       364               273
# 111       2.741577  1712651735       114                64
# 112       4.000000  1712716259       143               106
# 113      85.704202  1712869511       188                80
#
#                                        TransactionHash  \
# 0    0x4fb9751bd643b12ea246d0405e76c848994b27128a9f...
# 1    0xc248277fd2b27c1784d789272687c05064cd56bb6e50...
# 2    0x6710b3c1d8bd975c2d38e969ef3c405b6d99ca52c8af...
# 3    0x1624fda3865b9f142b3c0d1b705d4fec422669149c61...
# 4    0xfef2d5849018f0e5c7eb1e126d9eaa7ea3f696051c97...
# ..                                                 ...
# 109  0x36847665521a94fb88caad9ff99b5a0d7a18d333cb19...
# 110  0xa5f61cf9507f5c72a89d5397391dcdb38ef5d9291cd0...
# 111  0x26554f7623bccc8f3c0728f83d5546579b96c6fefb54...
# 112  0x5f79409a0bde7ce8ccd4d4aa24fe6e7c33073079dd77...
# 113  0xc44e5f3effef20bc126bea82e20e6915433816aacb9a...
#
#                                              BlockHash  BlockNumber
# 0    0x0ed58c0d3437c66943e7b6e093c693ceababd7670f9a...     19503077
# 1    0xf1a41037623872098ffaed8bc9d1f3f82e906a794bae...     19532459
# 2    0x436d11221d185e4a77d01a3848f99355f1bbe708e1b1...     19532612
# 3    0xe777fd4cbcf7603a8d8f7232c31d211f333dae168b08...     19533235
# 4    0xab396af9df4b8b2d1fc91eff7e72687963899f5944db...     19533517
# ..                                                 ...          ...
# 109  0x04f0421d0dbdc376cee5fa766b4afef9a36bc419dfa3...     19604559
# 110  0xcd76a013779c1cd555d78d0cec0628ac11079c77af7f...     19613039
# 111  0x3cf845327f006a1685dd5162d7daed1b2c3726c0ded8...     19616933
# 112  0x61c69620cc9af3cc7a303469941aba1617fb8405e83b...     19622263
# 113  0xe3f927bc4548f9afc329304114f0bba7719bc54a1584...     19634940
#
# [114 rows x 10 columns]

# %%
with open('./Prisma_TroveManagerOld_ABI.json') as f:
            abi = json.load(f)
smart_contract = w3.eth.contract(address='0xe0e255FD5281bEc3bB8fa1569a20097D9064E445', abi=abi)

supplies = smart_contract.events.CollateralSent().get_logs(fromBlock='earliest',
                                                       toBlock='latest')
supplies
# Out:
# (AttributeDict({'args': AttributeDict({'_to': '0xDb92A7a37A9e7D0a3Cab61e22DFf62FfEDfC2E4f',
#    '_amount': 1549971107790175748}),
#   'event': 'CollateralSent',
#   'logIndex': 90,
#   'transactionIndex': 11,
#   'transactionHash': HexBytes('0xf896f760ac27602d90a27d63ebf26b28ed4ec394c2540e7262ed04a9657f6318'),
#   'address': '0xe0e255FD5281bEc3bB8fa1569a20097D9064E445',
#   'blockHash': HexBytes('0x8c331182dedf7aebaedb1ca3bef4a9d8894fd2427e2e359beb5a633a8572e0f4'),
#   'blockNumber': 18043186}),
#  AttributeDict({'args': AttributeDict({'_to': '0xDb92A7a37A9e7D0a3Cab61e22DFf62FfEDfC2E4f',
#    '_amount': 1691767544280099852}),
#   'event': 'CollateralSent',
#   'logIndex': 73,
#   'transactionIndex': 14,
#   'transactionHash': HexBytes('0x4ba56dd1a0466e1255a6886ded9e47b07fe936cd11c03961ffc5bd72649aac99'),
#   'address': '0xe0e255FD5281bEc3bB8fa1569a20097D9064E445',
#   'blockHash': HexBytes('0x9ef57dc3288889d866cecf3aea9238c1a145632fc28d50f9c35cd3660aad414c'),
#   'blockNumber': 18043263}),
#  AttributeDict({'args': AttributeDict({'_to': '0x61311cD09e54A7E457fE3788aDfF7Da05d902Cf2',
#    '_amount': 1790000000000000000}),
#   'event': 'CollateralSent',
#   'logIndex': 30,
#   'transactionIndex': 6,
#   'transactionHash': HexBytes('0x7962b48075be949c1a84f214877a3b1541fbdb2bff349db7d6ed14d7397a5adb'),
#   'address': '0xe0e255FD5281bEc3bB8fa1569a20097D9064E445',
#   'blockHash': HexBytes('0x84e38a2648585fdb4f7a6d0e7d5e5e921996737d6e149f0f8c5a9bed94aa265f'),
#   'blockNumber': 18071053}),
#  AttributeDict({'args': AttributeDict({'_to': '0x6f9BB7e454f5B3eb2310343f0E99269dC2BB8A1d',
#    '_amount': 2400000000000000000}),
#   'event': 'CollateralSent',
#   'logIndex': 141,
#   'transactionIndex': 54,
#   'transactionHash': HexBytes('0x8f1a3a5fab43d985855b78f41b095f6fe28d985d434e50012cab592129b83248'),
#   'address': '0xe0e255FD5281bEc3bB8fa1569a20097D9064E445',
#   'blockHash': HexBytes('0x65094eb23f32b1d57f59b89685fbeab2b9c8cf2bea15d869362d49d58d25ee79'),
#   'blockNumber': 18089205}),
#  AttributeDict({'args': AttributeDict({'_to': '0x4dA792b5058F59162E1B619749a0Ce4E984D4841',
#    '_amount': 2398321292274375336}),
#   'event': 'CollateralSent',
#   'logIndex': 111,
#   'transactionIndex': 40,
#   'transactionHash': HexBytes('0x74a8d560b3dcf8e2bb5156b0693317b1536f3aba67c009590b9022296fedbc63'),
#   'address': '0xe0e255FD5281bEc3bB8fa1569a20097D9064E445',
#   'blockHash': HexBytes('0x6113c644f0c9dd69dd4170ccedf6cddb9347a166c9a834e3a247893b3ae4e713'),
#   'blockNumber': 18105714}),
#  AttributeDict({'args': AttributeDict({'_to': '0xA7E5a837382C4B2A484BD2AFAdc8B5A5f6d74e87',
#    '_amount': 2495000000000000000}),
#   'event': 'CollateralSent',
#   'logIndex': 109,
#   'transactionIndex': 61,
#   'transactionHash': HexBytes('0xf803bcd8206b296fbc47d9e5f90c1156d7165807c951e78df3b9603c1e09b477'),
#   'address': '0xe0e255FD5281bEc3bB8fa1569a20097D9064E445',
#   'blockHash': HexBytes('0x342910849455a29d3a877b41904a0645600efbb4ce7caa6021aef6bdcfbe7573'),
#   'blockNumber': 18113088}),
#  AttributeDict({'args': AttributeDict({'_to': '0xDf06A761D286C0ae835173236E1f12f1379E4977',
#    '_amount': 2202822027924947473}),
#   'event': 'CollateralSent',
#   'logIndex': 56,
#   'transactionIndex': 8,
#   'transactionHash': HexBytes('0xfd7b0b83c8cfa4e009e1064f67138d7d760d9ae9adf2637df7fa28fb8b1c16eb'),
#   'address': '0xe0e255FD5281bEc3bB8fa1569a20097D9064E445',
#   'blockHash': HexBytes('0xfb205a11242967ac934a110504de20b23db290d2e8987233d3bfb5cd29baebaf'),
#   'blockNumber': 18113251}),
#  AttributeDict({'args': AttributeDict({'_to': '0x47A0D24B34889277010026892B7612143d16bF13',
#    '_amount': 4617620923920442475}),
#   'event': 'CollateralSent',
#   'logIndex': 420,
#   'transactionIndex': 117,
#   'transactionHash': HexBytes('0xcad0ef971359ac5cf5ef2ba7f1048bff338ac5ca0da56da3d86485a2b3791d11'),
#   'address': '0xe0e255FD5281bEc3bB8fa1569a20097D9064E445',
#   'blockHash': HexBytes('0xc910e0bbbdab57c237766549622765bd9d7c28558bd6e9584c8cd5d943b85d75'),
#   'blockNumber': 18142569}),
#  AttributeDict({'args': AttributeDict({'_to': '0xEA3871fcDD47c06095b7ADe579E8365083dBb871',
#    '_amount': 3485483477691660827}),
#   'event': 'CollateralSent',
#   'logIndex': 95,
#   'transactionIndex': 37,
#   'transactionHash': HexBytes('0xf2807546b87d3ff6d445764f6e9c8a01fa63e37abc2959f7941c68fa0169db59'),
#   'address': '0xe0e255FD5281bEc3bB8fa1569a20097D9064E445',
#   'blockHash': HexBytes('0x06a3d28d5768b1e3492cfe0ba84cb0babc43af271ca88c4c10ef7c97a3656b24'),
#   'blockNumber': 18149398}),
#  AttributeDict({'args': AttributeDict({'_to': '0x51b0B7aB0aF8BA0E689299F00a733dE2F7080569',
#    '_amount': 9172763263432628915}),
#   'event': 'CollateralSent',
#   'logIndex': 164,
#   'transactionIndex': 75,
#   'transactionHash': HexBytes('0x461014983b259753e928f0580f33667ffc01ad1514f25fef4ad5160ea44c7a59'),
#   'address': '0xe0e255FD5281bEc3bB8fa1569a20097D9064E445',
#   'blockHash': HexBytes('0xc5e38ecf46cbc0b94e8661504384643bd86a72c4f49ada5d73ccaf6ec0d34fb6'),
#   'blockNumber': 18194072}),
#  AttributeDict({'args': AttributeDict({'_to': '0xddA42f12B8B2ccc6717c053A2b772baD24B08CbD',
#    '_amount': 100000000000000000}),
#   'event': 'CollateralSent',
#   'logIndex': 163,
#   'transactionIndex': 66,
#   'transactionHash': HexBytes('0xbfe3881d47fbfec1d245f9ed4d10ff81ba0e2b240754732013277d23385e2c92'),
#   'address': '0xe0e255FD5281bEc3bB8fa1569a20097D9064E445',
#   'blockHash': HexBytes('0xa4a6297bd2889478da09552ea624d91dbe14a9aa21da3f849efc6f84aaeafe33'),
#   'blockNumber': 18198990}),
#  AttributeDict({'args': AttributeDict({'_to': '0x1cb96c15327757d3F87eBcF6a2BA895E1437AB0c',
#    '_amount': 1986633332118082967}),
#   'event': 'CollateralSent',
#   'logIndex': 1301,
#   'transactionIndex': 215,
#   'transactionHash': HexBytes('0x65ee72568d49d33555115a1bd969fa0e7e01bacb8b5d0dddf9d22b0dcb2ba61f'),
#   'address': '0xe0e255FD5281bEc3bB8fa1569a20097D9064E445',
#   'blockHash': HexBytes('0x1153e08d273c5bd56a1b7f5c30b9b6f51a8805ed4b7e1a26eeaacfec18ade2d3'),
#   'blockNumber': 18199562}),
#  AttributeDict({'args': AttributeDict({'_to': '0xBA0C565110F65D181B9ff1D8A9f787B52857bB0c',
#    '_amount': 2651726168685009361}),
#   'event': 'CollateralSent',
#   'logIndex': 509,
#   'transactionIndex': 141,
#   'transactionHash': HexBytes('0x890381a2855c23a67860af177916ddc702efa6abde2bfc9a59705a8bd32adb40'),
#   'address': '0xe0e255FD5281bEc3bB8fa1569a20097D9064E445',
#   'blockHash': HexBytes('0xc920e88eaca0a2ba7e3d8a8b6d5d6d3e4cf54ffe5d13a5f653db3b032c5ed8d4'),
#   'blockNumber': 18199953}),
#  AttributeDict({'args': AttributeDict({'_to': '0x70436E8A9c2Ea2131529B4B825B8cBc7adaFc920',
#    '_amount': 2063465379208750052}),
#   'event': 'CollateralSent',
#   'logIndex': 119,
#   'transactionIndex': 31,
#   'transactionHash': HexBytes('0x496e37c8e60833ff6db34d385aafbe40fcee413875ae6ecb0818ab4ef0e198eb'),
#   'address': '0xe0e255FD5281bEc3bB8fa1569a20097D9064E445',
#   'blockHash': HexBytes('0xb344f842a2f25d2a81dece86592224e31a3efd31eda6b8befd425b23077f8784'),
#   'blockNumber': 18201036}),
#  AttributeDict({'args': AttributeDict({'_to': '0x2DE373887B9742162c9A5885DdB5DebEA8e4486d',
#    '_amount': 57204571522434394398}),
#   'event': 'CollateralSent',
#   'logIndex': 52,
#   'transactionIndex': 19,
#   'transactionHash': HexBytes('0xdaf2ea74b873e69250acc02af19bb43f10ce187fd19d6ae3382291af5286fc64'),
#   'address': '0xe0e255FD5281bEc3bB8fa1569a20097D9064E445',
#   'blockHash': HexBytes('0x1361667cc89c19c23c55e1e523bfdf4deed4d24de543aab70965772fc1cf3646'),
#   'blockNumber': 18215577}),
#  AttributeDict({'args': AttributeDict({'_to': '0xA8A9e2C366c56ce3968BbAc981D1a063e58dfA85',
#    '_amount': 1000000000000000000}),
#   'event': 'CollateralSent',
#   'logIndex': 347,
#   'transactionIndex': 159,
#   'transactionHash': HexBytes('0xfc4b7c98f1c66b0bcb2f51eded51a3fef098eb71ee90013053960d735f8bae4e'),
#   'address': '0xe0e255FD5281bEc3bB8fa1569a20097D9064E445',
#   'blockHash': HexBytes('0x1a099a46cb565bf189b8b61766bff58655c3d5c276d73e39d5bd998177e81ffe'),
#   'blockNumber': 18219454}),
#  AttributeDict({'args': AttributeDict({'_to': '0x26B5e14DBF21bfB62BFf869f5F4Bce8dbDDbcfcA',
#    '_amount': 170000000000000000}),
#   'event': 'CollateralSent',
#   'logIndex': 317,
#   'transactionIndex': 116,
#   'transactionHash': HexBytes('0x3143df149c2a6ebf1286f78707de57def2a7898e47f47ae43d320b7998cffe80'),
#   'address': '0xe0e255FD5281bEc3bB8fa1569a20097D9064E445',
#   'blockHash': HexBytes('0xe93babc8f91a5081e96728b0d0d1bbd44d79575fb80b13c131c6324f83e11644'),
#   'blockNumber': 18266099}),
#  AttributeDict({'args': AttributeDict({'_to': '0xeE5FF7D52AF2576b27FF9037D993C4F60431Af59',
#    '_amount': 9223630302029653927}),
#   'event': 'CollateralSent',
#   'logIndex': 41,
#   'transactionIndex': 38,
#   'transactionHash': HexBytes('0x9ed7e19bbd0f59a23d57d26d8a82a5be8ed7bd4a35b8550072cadee61340a99f'),
#   'address': '0xe0e255FD5281bEc3bB8fa1569a20097D9064E445',
#   'blockHash': HexBytes('0x696353c62f5e9a8948ad92904f96abc4c31b218f3316055fc5024d74ff846d6d'),
#   'blockNumber': 18271642}),
#  AttributeDict({'args': AttributeDict({'_to': '0xA0bB8934BD44A7900Add77FE21af2eFD9121B3C9',
#    '_amount': 1945517910159126845}),
#   'event': 'CollateralSent',
#   'logIndex': 84,
#   'transactionIndex': 31,
#   'transactionHash': HexBytes('0x5bb44fc951954da7de91463f2b64581ed42a9faff5eb45c501295f89e23ccb4f'),
#   'address': '0xe0e255FD5281bEc3bB8fa1569a20097D9064E445',
#   'blockHash': HexBytes('0x4f79f4feb32ea59adb2f5df0743240f75543212d15a1f084aea792b4555e6550'),
#   'blockNumber': 18273273}),
#  AttributeDict({'args': AttributeDict({'_to': '0x39ff305983289F7f8D9604E805a85F797D6435a8',
#    '_amount': 23238046247408275619}),
#   'event': 'CollateralSent',
#   'logIndex': 461,
#   'transactionIndex': 135,
#   'transactionHash': HexBytes('0xfadceaaad24c6eabbe24989f4ec1b5ce962fa971b2dc8072e119433c24a9ec67'),
#   'address': '0xe0e255FD5281bEc3bB8fa1569a20097D9064E445',
#   'blockHash': HexBytes('0x2ba38352824f8317955f14a9e0bd1af7df8029c7e929444022ad122d51e9b807'),
#   'blockNumber': 18277365}),
#  AttributeDict({'args': AttributeDict({'_to': '0x39ff305983289F7f8D9604E805a85F797D6435a8',
#    '_amount': 1667858900363654104}),
#   'event': 'CollateralSent',
#   'logIndex': 238,
#   'transactionIndex': 103,
#   'transactionHash': HexBytes('0xf9138afe33c55afbe7a7be748b335d3f6eb23acb95b0f3edbb86365996e99fa5'),
#   'address': '0xe0e255FD5281bEc3bB8fa1569a20097D9064E445',
#   'blockHash': HexBytes('0xa584a785ce31c9f43f3b6767583f72e2e5e714d00697f53b67963675ccf3ec40'),
#   'blockNumber': 18277403}),
#  AttributeDict({'args': AttributeDict({'_to': '0xF0694d5CBD6E9344cbf20647f754936f94bE4b8C',
#    '_amount': 1751564299471169919}),
#   'event': 'CollateralSent',
#   'logIndex': 205,
#   'transactionIndex': 28,
#   'transactionHash': HexBytes('0x7dd9ca7c8ed77e8f1c4c45bca477485db447537fea515f672dc800659b069c2a'),
#   'address': '0xe0e255FD5281bEc3bB8fa1569a20097D9064E445',
#   'blockHash': HexBytes('0xf3f2e7e8dffd57c2d70640a4a66864bc07541885c3c70a7e87f3f71133aaee2c'),
#   'blockNumber': 18287527}),
#  AttributeDict({'args': AttributeDict({'_to': '0xA7E5a837382C4B2A484BD2AFAdc8B5A5f6d74e87',
#    '_amount': 2396774207102466652}),
#   'event': 'CollateralSent',
#   'logIndex': 213,
#   'transactionIndex': 106,
#   'transactionHash': HexBytes('0x13a7f0536716b889b8d6d0fc414afb05d22ddb6db398abfdac3ebc35dc074bfb'),
#   'address': '0xe0e255FD5281bEc3bB8fa1569a20097D9064E445',
#   'blockHash': HexBytes('0x6c53e7bff457bd2b1a61f0fecacfe793a5b1cc289d676aaa5d61b733f557aac4'),
#   'blockNumber': 18311200}),
#  AttributeDict({'args': AttributeDict({'_to': '0x9cDB491354086AB189Dbb17360C33970B7298d3f',
#    '_amount': 1962305528552709170}),
#   'event': 'CollateralSent',
#   'logIndex': 271,
#   'transactionIndex': 60,
#   'transactionHash': HexBytes('0xbc6c909eccf7afb4e0604ffde1e09e080f236c2fa687a078491f77b14c059ef1'),
#   'address': '0xe0e255FD5281bEc3bB8fa1569a20097D9064E445',
#   'blockHash': HexBytes('0xd8c4d6d6fbf916847c339b5fea8f5453407e64cd3164d24153b8ba0afc828037'),
#   'blockNumber': 18311767}),
#  AttributeDict({'args': AttributeDict({'_to': '0x7B23f44c126C8D647Ab84751554FceBD34F39F98',
#    '_amount': 4613663456753523659}),
#   'event': 'CollateralSent',
#   'logIndex': 202,
#   'transactionIndex': 96,
#   'transactionHash': HexBytes('0x361a25e5ba1c704035de1c91e9f38bd648fa9be79bf75eb1f48df0a0b1a9cf07'),
#   'address': '0xe0e255FD5281bEc3bB8fa1569a20097D9064E445',
#   'blockHash': HexBytes('0xbd9b1d1ca425820bc83d836045fab21fede79d5ca30cf6b85445799cd5dd30cf'),
#   'blockNumber': 18329476}),
#  AttributeDict({'args': AttributeDict({'_to': '0x4c689018D571302001BA9e41CB7c1546fD0A434b',
#    '_amount': 2304882532492085054}),
#   'event': 'CollateralSent',
#   'logIndex': 369,
#   'transactionIndex': 108,
#   'transactionHash': HexBytes('0xf716402f0916a323ae47488b09a271d9d8b09590b5985152631be39ec741bfe5'),
#   'address': '0xe0e255FD5281bEc3bB8fa1569a20097D9064E445',
#   'blockHash': HexBytes('0xdfb5f6925f93a5565157efe1d9102e055f30b635af0bf24475f0d57652c41363'),
#   'blockNumber': 18335681}),
#  AttributeDict({'args': AttributeDict({'_to': '0xA8A9e2C366c56ce3968BbAc981D1a063e58dfA85',
#    '_amount': 666694654787855804}),
#   'event': 'CollateralSent',
#   'logIndex': 237,
#   'transactionIndex': 90,
#   'transactionHash': HexBytes('0xf6bbed9c0b228a64721c0dfdbe0cfde787bfeb1a22676b088ba1c3ca4f243781'),
#   'address': '0xe0e255FD5281bEc3bB8fa1569a20097D9064E445',
#   'blockHash': HexBytes('0x80dcb9c432dde408ce5d1880278195195b5fd488939a6fea552cf98a4ab6bfad'),
#   'blockNumber': 18337840}),
#  AttributeDict({'args': AttributeDict({'_to': '0x1F20384579c6D045C1c95ef17E20cB1ec97bF20f',
#    '_amount': 1100000000000000100}),
#   'event': 'CollateralSent',
#   'logIndex': 237,
#   'transactionIndex': 113,
#   'transactionHash': HexBytes('0xd640dcb045d7212e8b8ecac2ea83c0ef3b043df2c321061f4afb153d738b0364'),
#   'address': '0xe0e255FD5281bEc3bB8fa1569a20097D9064E445',
#   'blockHash': HexBytes('0x7324ac6a4414e70bd8eb050b5a302880a192c94077619dd0b8fcb04fdf003913'),
#   'blockNumber': 18360308}),
#  AttributeDict({'args': AttributeDict({'_to': '0xd5B12178161244cD1ac9EE4857B53f0B6e7c5a46',
#    '_amount': 300000000000000000}),
#   'event': 'CollateralSent',
#   'logIndex': 322,
#   'transactionIndex': 138,
#   'transactionHash': HexBytes('0xbff652292c862ad69e4fc6da7be80d205e5e0215ee31bb40165b904af6dac8db'),
#   'address': '0xe0e255FD5281bEc3bB8fa1569a20097D9064E445',
#   'blockHash': HexBytes('0xe7bd15a4e4d7bc630dd21786025ec14643126f2a86739fd25b6cbdc6d93f4c02'),
#   'blockNumber': 18364635}),
#  AttributeDict({'args': AttributeDict({'_to': '0x42f2d682D9cEe89A98347768337938eD8d18C266',
#    '_amount': 8252079386207323800}),
#   'event': 'CollateralSent',
#   'logIndex': 496,
#   'transactionIndex': 129,
#   'transactionHash': HexBytes('0x7a94200684cf12269317a727e8aa15c3445587539e21124c394c94f7eff0709d'),
#   'address': '0xe0e255FD5281bEc3bB8fa1569a20097D9064E445',
#   'blockHash': HexBytes('0x4f2b70b658c3be1df45e9c305fd1f6953f1a6727616579dea7cdf5af18f9fb66'),
#   'blockNumber': 18364924}),
#  AttributeDict({'args': AttributeDict({'_to': '0x42f2d682D9cEe89A98347768337938eD8d18C266',
#    '_amount': 1747920613792676200}),
#   'event': 'CollateralSent',
#   'logIndex': 219,
#   'transactionIndex': 129,
#   'transactionHash': HexBytes('0xe4d83f794260ca153d64e8d392381ba9815a5f65d5b6839df9decaba40b468e3'),
#   'address': '0xe0e255FD5281bEc3bB8fa1569a20097D9064E445',
#   'blockHash': HexBytes('0xf29fa73d2f30d319331f52c666c2ec4d559aef15f1f56615fe90a01c17f37eb9'),
#   'blockNumber': 18364948}),
#  AttributeDict({'args': AttributeDict({'_to': '0xcbdc53d424D5a2e5fef1776997352f10212c9883',
#    '_amount': 4400000000000000500}),
#   'event': 'CollateralSent',
#   'logIndex': 216,
#   'transactionIndex': 103,
#   'transactionHash': HexBytes('0x02763894431086fb68728d7f22b26af12dbbef6a6d7da124c9d7046c8ec97c1a'),
#   'address': '0xe0e255FD5281bEc3bB8fa1569a20097D9064E445',
#   'blockHash': HexBytes('0x2e7938ea3c383bcb64d08c6873dc982826b81a3a14622e22d3392e3eaa89d886'),
#   'blockNumber': 18380499}),
#  AttributeDict({'args': AttributeDict({'_to': '0xF6E0ccbfEa6405E3D6773C218C58C4273B602DBA',
#    '_amount': 2305508601280465817}),
#   'event': 'CollateralSent',
#   'logIndex': 152,
#   'transactionIndex': 26,
#   'transactionHash': HexBytes('0x6407ae49d5003439d0963dcf70b9a7452716b650ce9a6ec346fe84bc29e0eae2'),
#   'address': '0xe0e255FD5281bEc3bB8fa1569a20097D9064E445',
#   'blockHash': HexBytes('0x3235e282f7c18c08845e7b42b5be13b355d1e269af0bc2b8dd9b053612d1b09f'),
#   'blockNumber': 18382038}),
#  AttributeDict({'args': AttributeDict({'_to': '0x61F72FE1e4FF809A2ecA0b191C608599A192E1a1',
#    '_amount': 4722910314206047937}),
#   'event': 'CollateralSent',
#   'logIndex': 86,
#   'transactionIndex': 12,
#   'transactionHash': HexBytes('0x4593bcedf61f2b556a89b4a554317b0eb17633698a67d56f7e980225f1ef3afc'),
#   'address': '0xe0e255FD5281bEc3bB8fa1569a20097D9064E445',
#   'blockHash': HexBytes('0x45f7419cfae79d0957a09d803c12d0a5b9c2f51bd3a8628d1208ef5b99aa7107'),
#   'blockNumber': 18394222}),
#  AttributeDict({'args': AttributeDict({'_to': '0xfdCE0267803C6a0D209D3721d2f01Fd618e9CBF8',
#    '_amount': 128957691165566937}),
#   'event': 'CollateralSent',
#   'logIndex': 250,
#   'transactionIndex': 163,
#   'transactionHash': HexBytes('0x1d61355e703932755a50cf35a6afdba27ed25441a31e101354f86bcb9faff996'),
#   'address': '0xe0e255FD5281bEc3bB8fa1569a20097D9064E445',
#   'blockHash': HexBytes('0x07b6ab9015b9571aa5fb0305bf76a475938293fbc6099f8ccf2d0c4b85674e47'),
#   'blockNumber': 18394381}),
#  AttributeDict({'args': AttributeDict({'_to': '0x8A8e9730646EFd1e57453054F1a6366897d7cb1C',
#    '_amount': 18742188862653700702}),
#   'event': 'CollateralSent',
#   'logIndex': 254,
#   'transactionIndex': 163,
#   'transactionHash': HexBytes('0x1d61355e703932755a50cf35a6afdba27ed25441a31e101354f86bcb9faff996'),
#   'address': '0xe0e255FD5281bEc3bB8fa1569a20097D9064E445',
#   'blockHash': HexBytes('0x07b6ab9015b9571aa5fb0305bf76a475938293fbc6099f8ccf2d0c4b85674e47'),
#   'blockNumber': 18394381}),
#  AttributeDict({'args': AttributeDict({'_to': '0xb7CE28C2766a553506C2aE76D7ad3e554Cd2c102',
#    '_amount': 34502203714870970977}),
#   'event': 'CollateralSent',
#   'logIndex': 294,
#   'transactionIndex': 107,
#   'transactionHash': HexBytes('0xfddeb4a0617fa674c9c5e6850c72f186b452f83b4758acb7a69e16b44d38d993'),
#   'address': '0xe0e255FD5281bEc3bB8fa1569a20097D9064E445',
#   'blockHash': HexBytes('0x17037c8b9f5d9f914eb030a770755eb607126b9ad7b0023c7b9cf46ea1b6e6e3'),
#   'blockNumber': 18404568}),
#  AttributeDict({'args': AttributeDict({'_to': '0xddA42f12B8B2ccc6717c053A2b772baD24B08CbD',
#    '_amount': 1000000000000000000}),
#   'event': 'CollateralSent',
#   'logIndex': 469,
#   'transactionIndex': 192,
#   'transactionHash': HexBytes('0x4017c8b21077aefadf3514c97b4532e271fdca5c4dc173568e6364d2f3ff99f4'),
#   'address': '0xe0e255FD5281bEc3bB8fa1569a20097D9064E445',
#   'blockHash': HexBytes('0x8de70b0ab1c61e27c89c06ae05cdc2afefe5caaf60843706e153333a46438600'),
#   'blockNumber': 18414815}),
#  AttributeDict({'args': AttributeDict({'_to': '0x3090eeF25c05c6CF6fF2988646EE27Aa2f5C0178',
#    '_amount': 9000000000000000000}),
#   'event': 'CollateralSent',
#   'logIndex': 146,
#   'transactionIndex': 34,
#   'transactionHash': HexBytes('0xe5d83a46a1f0216c0495a14da5f739d65faae23c8e23fa04bd692940f67f90e6'),
#   'address': '0xe0e255FD5281bEc3bB8fa1569a20097D9064E445',
#   'blockHash': HexBytes('0xcd6a6c4af222db0e8964ebc110f0c82210b8090993841ced9fa2d323a2d84334'),
#   'blockNumber': 18417957}),
#  AttributeDict({'args': AttributeDict({'_to': '0xe85070Bf5B50eC06EF31aB0ed3DB284649D872b8',
#    '_amount': 5500000000000000000}),
#   'event': 'CollateralSent',
#   'logIndex': 329,
#   'transactionIndex': 124,
#   'transactionHash': HexBytes('0xaac5f0a26350fff6f904acfe5740ff8de157762d0511e07c0f36068561bb764a'),
#   'address': '0xe0e255FD5281bEc3bB8fa1569a20097D9064E445',
#   'blockHash': HexBytes('0x6a3088160329027d27c1b9dc5d2b752cd49f1bd4de24b7c949abc71e428afeec'),
#   'blockNumber': 18419004}),
#  AttributeDict({'args': AttributeDict({'_to': '0x1325e1c9eEEbdEB5050673BCF2887E093a7b264C',
#    '_amount': 100000000000000000000}),
#   'event': 'CollateralSent',
#   'logIndex': 666,
#   'transactionIndex': 165,
#   'transactionHash': HexBytes('0xb22b23b9f09f2c2bd4f2a8b68dcdda38e5ab47ad5516e59bd585961534dc514b'),
#   'address': '0xe0e255FD5281bEc3bB8fa1569a20097D9064E445',
#   'blockHash': HexBytes('0xcd797206ff53a8df1e59497070416705f182bd4ac464e61c6fb8eb42ef0afc9b'),
#   'blockNumber': 18419790}),
#  AttributeDict({'args': AttributeDict({'_to': '0xfdCE0267803C6a0D209D3721d2f01Fd618e9CBF8',
#    '_amount': 193899474492559017}),
#   'event': 'CollateralSent',
#   'logIndex': 545,
#   'transactionIndex': 190,
#   'transactionHash': HexBytes('0x57171081ce6247305d1410ab6e21f8034e095ee54472ede66152ccd44cb02bcb'),
#   'address': '0xe0e255FD5281bEc3bB8fa1569a20097D9064E445',
#   'blockHash': HexBytes('0x877fb41ba984171c091dca07f800ec6437aca650f31e09828e84cdd0ec80c461'),
#   'blockNumber': 18423324}),
#  AttributeDict({'args': AttributeDict({'_to': '0x8A8e9730646EFd1e57453054F1a6366897d7cb1C',
#    '_amount': 25521000127715962994}),
#   'event': 'CollateralSent',
#   'logIndex': 549,
#   'transactionIndex': 190,
#   'transactionHash': HexBytes('0x57171081ce6247305d1410ab6e21f8034e095ee54472ede66152ccd44cb02bcb'),
#   'address': '0xe0e255FD5281bEc3bB8fa1569a20097D9064E445',
#   'blockHash': HexBytes('0x877fb41ba984171c091dca07f800ec6437aca650f31e09828e84cdd0ec80c461'),
#   'blockNumber': 18423324}),
#  AttributeDict({'args': AttributeDict({'_to': '0xB968DCaD041665faFA8289177330300C01c0ccf9',
#    '_amount': 3000000000000000000}),
#   'event': 'CollateralSent',
#   'logIndex': 158,
#   'transactionIndex': 138,
#   'transactionHash': HexBytes('0xd7d35b28738bb26208d9b4bd22d9ab742c32b690cb4d79d202cd93a2bb3daa92'),
#   'address': '0xe0e255FD5281bEc3bB8fa1569a20097D9064E445',
#   'blockHash': HexBytes('0x2ea7efcd69f4f17ff7bb5f33c9aa9e2b607406fe7ea8b144a9a2f32add7a96a7'),
#   'blockNumber': 18423810}),
#  AttributeDict({'args': AttributeDict({'_to': '0x5e95b00EB048bA226e37f5FcBaB2eBd8B530C83b',
#    '_amount': 300000000000000000}),
#   'event': 'CollateralSent',
#   'logIndex': 191,
#   'transactionIndex': 115,
#   'transactionHash': HexBytes('0xc0d3636209c71f75647fd5cf51f6ffcd3ab710996f9e3a8037f4899faab3d02e'),
#   'address': '0xe0e255FD5281bEc3bB8fa1569a20097D9064E445',
#   'blockHash': HexBytes('0x7b9e0ec83e0497ccf7215e3f4517d683fb631462b611bc2cdfe884696bdc76c3'),
#   'blockNumber': 18426335}),
#  AttributeDict({'args': AttributeDict({'_to': '0xFb5A99E4e33FF4d0234394eb2b93b67D7aB2590F',
#    '_amount': 16978293368493267603}),
#   'event': 'CollateralSent',
#   'logIndex': 82,
#   'transactionIndex': 16,
#   'transactionHash': HexBytes('0x5ee1776c7898216ba93a165f706a8abc1266fcdda7aeeeeded5186b56bcb0bc4'),
#   'address': '0xe0e255FD5281bEc3bB8fa1569a20097D9064E445',
#   'blockHash': HexBytes('0xb19a62e916604ed963367c98b7b6a39d69413014f5dcb2fd107e84e91fb1f218'),
#   'blockNumber': 18428340}),
#  AttributeDict({'args': AttributeDict({'_to': '0xC6efe18B9E6031C197BDD275198c6549BB3BC271',
#    '_amount': 300000000000000000}),
#   'event': 'CollateralSent',
#   'logIndex': 0,
#   'transactionIndex': 2,
#   'transactionHash': HexBytes('0xe20a918ab1aa76a4227d94873887f6f3be489b0dbe5d65847d06866eb5f81857'),
#   'address': '0xe0e255FD5281bEc3bB8fa1569a20097D9064E445',
#   'blockHash': HexBytes('0x6cc87800464681764ec0f96393fabbc866785886a457efe7ec6450e3123ab68e'),
#   'blockNumber': 18429571}),
#  AttributeDict({'args': AttributeDict({'_to': '0x61F72FE1e4FF809A2ecA0b191C608599A192E1a1',
#    '_amount': 4494692359536070021}),
#   'event': 'CollateralSent',
#   'logIndex': 224,
#   'transactionIndex': 119,
#   'transactionHash': HexBytes('0x653c3d146589248371bc52dc271da01b5ee54c8603041c66a460d1fc1814e614'),
#   'address': '0xe0e255FD5281bEc3bB8fa1569a20097D9064E445',
#   'blockHash': HexBytes('0x8c1ba1e9292a21a8e4334610cbfc208f331ce3d1b19516a5c7551d8e90a6c978'),
#   'blockNumber': 18435126}),
#  AttributeDict({'args': AttributeDict({'_to': '0x713C89621B8A97B1C401793Efc4796377bD55E49',
#    '_amount': 2218491629130410455}),
#   'event': 'CollateralSent',
#   'logIndex': 67,
#   'transactionIndex': 7,
#   'transactionHash': HexBytes('0xa232711dc6339671649e976bc922df863450d423159c09d3165fa69e4292a0bb'),
#   'address': '0xe0e255FD5281bEc3bB8fa1569a20097D9064E445',
#   'blockHash': HexBytes('0x7e6f5b317b752e6b3bd7ae58cbb83b8e265358026e3d78e41792b7a2551145a8'),
#   'blockNumber': 18436294}),
#  AttributeDict({'args': AttributeDict({'_to': '0xE1a24535D1Dd36C2B1508e11138960C3950Ab161',
#    '_amount': 4608754842707504404}),
#   'event': 'CollateralSent',
#   'logIndex': 313,
#   'transactionIndex': 121,
#   'transactionHash': HexBytes('0x4f0c9af73ac2783b0d9c4a903e64c35d825a5bc5d7b94d1ec9cbca07e0ecce85'),
#   'address': '0xe0e255FD5281bEc3bB8fa1569a20097D9064E445',
#   'blockHash': HexBytes('0x9299e79f9df8ce6fb7f733da47b70516e0f958ad9abe3374ef627e20f25e9208'),
#   'blockNumber': 18436313}),
#  AttributeDict({'args': AttributeDict({'_to': '0x6f6bb64c535746cF526EEAc9b3263F6a1a06B880',
#    '_amount': 2341085498540024562}),
#   'event': 'CollateralSent',
#   'logIndex': 142,
#   'transactionIndex': 36,
#   'transactionHash': HexBytes('0x7769a81484d9cb364f3ab3012477db91809828f236d8babf3bb4afbbc23316cc'),
#   'address': '0xe0e255FD5281bEc3bB8fa1569a20097D9064E445',
#   'blockHash': HexBytes('0x36f1a8d18749df977b6fdba483a06f3ea6767aac415ff0103e727116d1979a6a'),
#   'blockNumber': 18436351}),
#  AttributeDict({'args': AttributeDict({'_to': '0x69d089132184F5e8C4B1aF4382F6d19f8261A834',
#    '_amount': 2298481428311717757}),
#   'event': 'CollateralSent',
#   'logIndex': 88,
#   'transactionIndex': 34,
#   'transactionHash': HexBytes('0x41a1e871dc678cea54bd1d894daa8f77310cacd5e317b33ecd624d4102a44a9e'),
#   'address': '0xe0e255FD5281bEc3bB8fa1569a20097D9064E445',
#   'blockHash': HexBytes('0x87f5f72925f6ec5eb1174852d301edd0155a246e88f3d134208588f69185c2ad'),
#   'blockNumber': 18436378}),
#  AttributeDict({'args': AttributeDict({'_to': '0xfdCE0267803C6a0D209D3721d2f01Fd618e9CBF8',
#    '_amount': 20687700742476889}),
#   'event': 'CollateralSent',
#   'logIndex': 462,
#   'transactionIndex': 165,
#   'transactionHash': HexBytes('0x17500598d8ea238b2f88ff901fca0b276407ea51f64543663ae30cc22777dd30'),
#   'address': '0xe0e255FD5281bEc3bB8fa1569a20097D9064E445',
#   'blockHash': HexBytes('0xc69fa46f0951e32fe0cdd6d7347e527b806ef2cd49d445c0c0a6e9d52b88eca6'),
#   'blockNumber': 18437308}),
#  AttributeDict({'args': AttributeDict({'_to': '0x4d30484C796162E9f933A9Edd4981F4aa808D3C6',
#    '_amount': 3719101119101451857}),
#   'event': 'CollateralSent',
#   'logIndex': 466,
#   'transactionIndex': 165,
#   'transactionHash': HexBytes('0x17500598d8ea238b2f88ff901fca0b276407ea51f64543663ae30cc22777dd30'),
#   'address': '0xe0e255FD5281bEc3bB8fa1569a20097D9064E445',
#   'blockHash': HexBytes('0xc69fa46f0951e32fe0cdd6d7347e527b806ef2cd49d445c0c0a6e9d52b88eca6'),
#   'blockNumber': 18437308}),
#  AttributeDict({'args': AttributeDict({'_to': '0xfdCE0267803C6a0D209D3721d2f01Fd618e9CBF8',
#    '_amount': 342183582005023842}),
#   'event': 'CollateralSent',
#   'logIndex': 310,
#   'transactionIndex': 95,
#   'transactionHash': HexBytes('0x37b88c6c6d3bdcb3ae5a07686d01b1a0516af79369788326375597a49ae7adac'),
#   'address': '0xe0e255FD5281bEc3bB8fa1569a20097D9064E445',
#   'blockHash': HexBytes('0x6130b2f1e51d3b4a28d6aaa594a80db998496d0fa3eaba89e575fbabf39cd18a'),
#   'blockNumber': 18437336}),
#  AttributeDict({'args': AttributeDict({'_to': '0x4d30484C796162E9f933A9Edd4981F4aa808D3C6',
#    '_amount': 37017593302144359950}),
#   'event': 'CollateralSent',
#   'logIndex': 314,
#   'transactionIndex': 95,
#   'transactionHash': HexBytes('0x37b88c6c6d3bdcb3ae5a07686d01b1a0516af79369788326375597a49ae7adac'),
#   'address': '0xe0e255FD5281bEc3bB8fa1569a20097D9064E445',
#   'blockHash': HexBytes('0x6130b2f1e51d3b4a28d6aaa594a80db998496d0fa3eaba89e575fbabf39cd18a'),
#   'blockNumber': 18437336}),
#  AttributeDict({'args': AttributeDict({'_to': '0xd5F5902901BBe4221c633A4A491a21aB7E4AC091',
#    '_amount': 2075716162830548767}),
#   'event': 'CollateralSent',
#   'logIndex': 227,
#   'transactionIndex': 92,
#   'transactionHash': HexBytes('0x9602b337794dc785951b1fe4358ce38586a66d8e8d32f729091ca47bd49dda69'),
#   'address': '0xe0e255FD5281bEc3bB8fa1569a20097D9064E445',
#   'blockHash': HexBytes('0xfaf0b8351a6b5a1f60cc9c4e0efaa07aca82c6845354b8d9aca3de936b826236'),
#   'blockNumber': 18440197}),
#  AttributeDict({'args': AttributeDict({'_to': '0x5962A65D9Faeab29F47971273f1d34C1B23F95c6',
#    '_amount': 2370736603099451766}),
#   'event': 'CollateralSent',
#   'logIndex': 144,
#   'transactionIndex': 13,
#   'transactionHash': HexBytes('0xe9603b4f6262fc79d3591bf1e2c3c0bc40e1314ca76842f4e2d1af08ab670426'),
#   'address': '0xe0e255FD5281bEc3bB8fa1569a20097D9064E445',
#   'blockHash': HexBytes('0xd7920569e922e2565232eca1ce08d15e7ff07dc60157c0c6e535e6daa6db351a'),
#   'blockNumber': 18441551}),
#  AttributeDict({'args': AttributeDict({'_to': '0xA8A9e2C366c56ce3968BbAc981D1a063e58dfA85',
#    '_amount': 950000000000000000}),
#   'event': 'CollateralSent',
#   'logIndex': 264,
#   'transactionIndex': 136,
#   'transactionHash': HexBytes('0x41b89adf9ef36ae35769d28dd6ffa51d41e10fef4ff93cfc27518890f56e90b0'),
#   'address': '0xe0e255FD5281bEc3bB8fa1569a20097D9064E445',
#   'blockHash': HexBytes('0xcff163b3c35ad6c922c147b2ce2c637b9bfad8c2488c61f7f55402dfd418354a'),
#   'blockNumber': 18442126}),
#  AttributeDict({'args': AttributeDict({'_to': '0x7C43a9C3b85619be2F7C0a4D676eCd373f63b73C',
#    '_amount': 1500000000000000000}),
#   'event': 'CollateralSent',
#   'logIndex': 355,
#   'transactionIndex': 157,
#   'transactionHash': HexBytes('0xae84de2129e9cfdd2c77a4b5d4fb4dce2fc2418d7f46e91c75147e0652e70958'),
#   'address': '0xe0e255FD5281bEc3bB8fa1569a20097D9064E445',
#   'blockHash': HexBytes('0x48af3239160705c4323d81781bc793b45a7cc863462272af3d592841f120fe1f'),
#   'blockNumber': 18442515}),
#  AttributeDict({'args': AttributeDict({'_to': '0x7C43a9C3b85619be2F7C0a4D676eCd373f63b73C',
#    '_amount': 323500000000000000000}),
#   'event': 'CollateralSent',
#   'logIndex': 288,
#   'transactionIndex': 112,
#   'transactionHash': HexBytes('0x773e8a772e638491b7240f66cd132b85896ff13f7246f4c6b08850eddc71bfe2'),
#   'address': '0xe0e255FD5281bEc3bB8fa1569a20097D9064E445',
#   'blockHash': HexBytes('0x2302efb92466e1862d2124386168bfb2f8fe94099f66f38133b9818248ea0a7c'),
#   'blockNumber': 18443134}),
#  AttributeDict({'args': AttributeDict({'_to': '0xfdCE0267803C6a0D209D3721d2f01Fd618e9CBF8',
#    '_amount': 368393068563361728}),
#   'event': 'CollateralSent',
#   'logIndex': 259,
#   'transactionIndex': 35,
#   'transactionHash': HexBytes('0xc162c9a282b4fbdab483f86d723a038554ef10320c9bb379ed5ba0c70d9ddf33'),
#   'address': '0xe0e255FD5281bEc3bB8fa1569a20097D9064E445',
#   'blockHash': HexBytes('0xeedb43817d642ee05a0d8fc215df36fc31c924c511c495d894de0ac0080dcd57'),
#   'blockNumber': 18443866}),
#  AttributeDict({'args': AttributeDict({'_to': '0x4d30484C796162E9f933A9Edd4981F4aa808D3C6',
#    '_amount': 36860092963002051065}),
#   'event': 'CollateralSent',
#   'logIndex': 263,
#   'transactionIndex': 35,
#   'transactionHash': HexBytes('0xc162c9a282b4fbdab483f86d723a038554ef10320c9bb379ed5ba0c70d9ddf33'),
#   'address': '0xe0e255FD5281bEc3bB8fa1569a20097D9064E445',
#   'blockHash': HexBytes('0xeedb43817d642ee05a0d8fc215df36fc31c924c511c495d894de0ac0080dcd57'),
#   'blockNumber': 18443866}),
#  AttributeDict({'args': AttributeDict({'_to': '0xDB611d682cb1ad72fcBACd944a8a6e2606a6d158',
#    '_amount': 12101114411680225207}),
#   'event': 'CollateralSent',
#   'logIndex': 291,
#   'transactionIndex': 57,
#   'transactionHash': HexBytes('0x2a715de768e2ff2b3ca367b1ff21f3670ab2e065154ef315ee1978ce0f0a1d79'),
#   'address': '0xe0e255FD5281bEc3bB8fa1569a20097D9064E445',
#   'blockHash': HexBytes('0xced6477aecbcb1c0c8e35b3497332c27fb368f938441ea52a8284581e7e71ad8'),
#   'blockNumber': 18444031}),
#  AttributeDict({'args': AttributeDict({'_to': '0xfdCE0267803C6a0D209D3721d2f01Fd618e9CBF8',
#    '_amount': 215791647966084564}),
#   'event': 'CollateralSent',
#   'logIndex': 256,
#   'transactionIndex': 141,
#   'transactionHash': HexBytes('0x79eda51174efc7a32433efa9a9c850ea62e5a546369afa670a19c201bbc13ad1'),
#   'address': '0xe0e255FD5281bEc3bB8fa1569a20097D9064E445',
#   'blockHash': HexBytes('0x423de34dc1d4a9e33ce0921ac2944a27eb8e2d60228923ba386d9ba3e73c22bb'),
#   'blockNumber': 18444145}),
#  AttributeDict({'args': AttributeDict({'_to': '0x4d30484C796162E9f933A9Edd4981F4aa808D3C6',
#    '_amount': 18446523813566223593}),
#   'event': 'CollateralSent',
#   'logIndex': 260,
#   'transactionIndex': 141,
#   'transactionHash': HexBytes('0x79eda51174efc7a32433efa9a9c850ea62e5a546369afa670a19c201bbc13ad1'),
#   'address': '0xe0e255FD5281bEc3bB8fa1569a20097D9064E445',
#   'blockHash': HexBytes('0x423de34dc1d4a9e33ce0921ac2944a27eb8e2d60228923ba386d9ba3e73c22bb'),
#   'blockNumber': 18444145}),
#  AttributeDict({'args': AttributeDict({'_to': '0xfdCE0267803C6a0D209D3721d2f01Fd618e9CBF8',
#    '_amount': 355622221496610369}),
#   'event': 'CollateralSent',
#   'logIndex': 194,
#   'transactionIndex': 56,
#   'transactionHash': HexBytes('0xc917552b2abe9cfc97e4a83b000be73769614f0f50edaf16e3bf52ea1ae6debd'),
#   'address': '0xe0e255FD5281bEc3bB8fa1569a20097D9064E445',
#   'blockHash': HexBytes('0xb733ee42ffca8464862ea4f780540e849cc28bcbb06751caa2742ebf82fafabe'),
#   'blockNumber': 18445781}),
#  AttributeDict({'args': AttributeDict({'_to': '0x3AA228a80F50763045BDfc45012dA124Bd0a6809',
#    '_amount': 27659797037656014614}),
#   'event': 'CollateralSent',
#   'logIndex': 198,
#   'transactionIndex': 56,
#   'transactionHash': HexBytes('0xc917552b2abe9cfc97e4a83b000be73769614f0f50edaf16e3bf52ea1ae6debd'),
#   'address': '0xe0e255FD5281bEc3bB8fa1569a20097D9064E445',
#   'blockHash': HexBytes('0xb733ee42ffca8464862ea4f780540e849cc28bcbb06751caa2742ebf82fafabe'),
#   'blockNumber': 18445781}),
#  AttributeDict({'args': AttributeDict({'_to': '0xfdCE0267803C6a0D209D3721d2f01Fd618e9CBF8',
#    '_amount': 437122548555159376}),
#   'event': 'CollateralSent',
#   'logIndex': 98,
#   'transactionIndex': 14,
#   'transactionHash': HexBytes('0x1c42d2f3d30458497d67e6ccd6f82feb753ce9e8d7acc1388af8c8f11bcc85f4'),
#   'address': '0xe0e255FD5281bEc3bB8fa1569a20097D9064E445',
#   'blockHash': HexBytes('0x188895009ec2ddd7c106b817f5f59381f241b31e1457895b621a201260742a75'),
#   'blockNumber': 18445790}),
#  AttributeDict({'args': AttributeDict({'_to': '0x4d30484C796162E9f933A9Edd4981F4aa808D3C6',
#    '_amount': 27578296710597465616}),
#   'event': 'CollateralSent',
#   'logIndex': 102,
#   'transactionIndex': 14,
#   'transactionHash': HexBytes('0x1c42d2f3d30458497d67e6ccd6f82feb753ce9e8d7acc1388af8c8f11bcc85f4'),
#   'address': '0xe0e255FD5281bEc3bB8fa1569a20097D9064E445',
#   'blockHash': HexBytes('0x188895009ec2ddd7c106b817f5f59381f241b31e1457895b621a201260742a75'),
#   'blockNumber': 18445790}),
#  AttributeDict({'args': AttributeDict({'_to': '0xfdCE0267803C6a0D209D3721d2f01Fd618e9CBF8',
#    '_amount': 363537038111051798}),
#   'event': 'CollateralSent',
#   'logIndex': 240,
#   'transactionIndex': 98,
#   'transactionHash': HexBytes('0x8a5b706b4140188492e51669ed9ce29e148130701c74e4b20e287f36c77a15e7'),
#   'address': '0xe0e255FD5281bEc3bB8fa1569a20097D9064E445',
#   'blockHash': HexBytes('0xa27b5eca787eb6c0a7e746586014b5499a2dcaeedea0dad0116d05dfbf532fed'),
#   'blockNumber': 18448538}),
#  AttributeDict({'args': AttributeDict({'_to': '0x4d30484C796162E9f933A9Edd4981F4aa808D3C6',
#    '_amount': 25833036419783558281}),
#   'event': 'CollateralSent',
#   'logIndex': 244,
#   'transactionIndex': 98,
#   'transactionHash': HexBytes('0x8a5b706b4140188492e51669ed9ce29e148130701c74e4b20e287f36c77a15e7'),
#   'address': '0xe0e255FD5281bEc3bB8fa1569a20097D9064E445',
#   'blockHash': HexBytes('0xa27b5eca787eb6c0a7e746586014b5499a2dcaeedea0dad0116d05dfbf532fed'),
#   'blockNumber': 18448538}),
#  AttributeDict({'args': AttributeDict({'_to': '0xfdCE0267803C6a0D209D3721d2f01Fd618e9CBF8',
#    '_amount': 353840836689279882}),
#   'event': 'CollateralSent',
#   'logIndex': 218,
#   'transactionIndex': 108,
#   'transactionHash': HexBytes('0xba6a6209dbce9c9735fc9db6e5ab885c7404f5e6bc40bd76a9e10e13b15ecd5a'),
#   'address': '0xe0e255FD5281bEc3bB8fa1569a20097D9064E445',
#   'blockHash': HexBytes('0xa7ba9d3b8dd8c9b1725699633efa2f7f3b5d8fbb37df40adb1f7a337cd6adbf4'),
#   'blockNumber': 18449720}),
#  AttributeDict({'args': AttributeDict({'_to': '0x4d30484C796162E9f933A9Edd4981F4aa808D3C6',
#    '_amount': 23995924587869924414}),
#   'event': 'CollateralSent',
#   'logIndex': 222,
#   'transactionIndex': 108,
#   'transactionHash': HexBytes('0xba6a6209dbce9c9735fc9db6e5ab885c7404f5e6bc40bd76a9e10e13b15ecd5a'),
#   'address': '0xe0e255FD5281bEc3bB8fa1569a20097D9064E445',
#   'blockHash': HexBytes('0xa7ba9d3b8dd8c9b1725699633efa2f7f3b5d8fbb37df40adb1f7a337cd6adbf4'),
#   'blockNumber': 18449720}),
#  AttributeDict({'args': AttributeDict({'_to': '0xB1daFE66e7E65608f789908f28e482197aAa8F84',
#    '_amount': 723569324864854389}),
#   'event': 'CollateralSent',
#   'logIndex': 219,
#   'transactionIndex': 120,
#   'transactionHash': HexBytes('0x1de789738635392340017a9dcb088b0dfedb48122283b1ea8ca497fc37e2f624'),
#   'address': '0xe0e255FD5281bEc3bB8fa1569a20097D9064E445',
#   'blockHash': HexBytes('0xbd07c7dfbb6bd0efe79ba65b24dd83cf7b6085a43fd58f42982cc572c694dc13'),
#   'blockNumber': 18454765}),
#  AttributeDict({'args': AttributeDict({'_to': '0xfdCE0267803C6a0D209D3721d2f01Fd618e9CBF8',
#    '_amount': 39884540426451522}),
#   'event': 'CollateralSent',
#   'logIndex': 285,
#   'transactionIndex': 142,
#   'transactionHash': HexBytes('0x3a5b701a9bb17ce942bc3ab096767a8de5c6a51af096269565d7b937affbcab9'),
#   'address': '0xe0e255FD5281bEc3bB8fa1569a20097D9064E445',
#   'blockHash': HexBytes('0x48cbddbebb5f0d7325a9f6ae3e247a932c827b12d8b7a37dba0b321c839e392d'),
#   'blockNumber': 18458640}),
#  AttributeDict({'args': AttributeDict({'_to': '0xD1Abe5DB14d073883f2084c2aF105652102BDefc',
#    '_amount': 5452254319618677663}),
#   'event': 'CollateralSent',
#   'logIndex': 289,
#   'transactionIndex': 142,
#   'transactionHash': HexBytes('0x3a5b701a9bb17ce942bc3ab096767a8de5c6a51af096269565d7b937affbcab9'),
#   'address': '0xe0e255FD5281bEc3bB8fa1569a20097D9064E445',
#   'blockHash': HexBytes('0x48cbddbebb5f0d7325a9f6ae3e247a932c827b12d8b7a37dba0b321c839e392d'),
#   'blockNumber': 18458640}),
#  AttributeDict({'args': AttributeDict({'_to': '0xfdCE0267803C6a0D209D3721d2f01Fd618e9CBF8',
#    '_amount': 356124746539364484}),
#   'event': 'CollateralSent',
#   'logIndex': 199,
#   'transactionIndex': 32,
#   'transactionHash': HexBytes('0xdaed9070b3aaecf056383ebc744ca594c3a01f715cb4db09b8d9f8b38471eb89'),
#   'address': '0xe0e255FD5281bEc3bB8fa1569a20097D9064E445',
#   'blockHash': HexBytes('0x066aecdb5804e22d914f4b343b66c29540c85f0482755d9f19ad1a9437b6cac9'),
#   'blockNumber': 18463926}),
#  AttributeDict({'args': AttributeDict({'_to': '0x4d30484C796162E9f933A9Edd4981F4aa808D3C6',
#    '_amount': 36953340568443920622}),
#   'event': 'CollateralSent',
#   'logIndex': 203,
#   'transactionIndex': 32,
#   'transactionHash': HexBytes('0xdaed9070b3aaecf056383ebc744ca594c3a01f715cb4db09b8d9f8b38471eb89'),
#   'address': '0xe0e255FD5281bEc3bB8fa1569a20097D9064E445',
#   'blockHash': HexBytes('0x066aecdb5804e22d914f4b343b66c29540c85f0482755d9f19ad1a9437b6cac9'),
#   'blockNumber': 18463926}),
#  AttributeDict({'args': AttributeDict({'_to': '0x6C50bF7Ee47508898362a406c7e271B9988fd20C',
#    '_amount': 4623543534434047761}),
#   'event': 'CollateralSent',
#   'logIndex': 395,
#   'transactionIndex': 119,
#   'transactionHash': HexBytes('0xef074ca91cd8d6f1e1083f1723caa9798689bd8523b69a2b686b2c3ad7ee5bc2'),
#   'address': '0xe0e255FD5281bEc3bB8fa1569a20097D9064E445',
#   'blockHash': HexBytes('0x447fa1e77ab790ec39eaa989c5934ecb56be27103109b27948a484252a465ed0'),
#   'blockNumber': 18465761}),
#  AttributeDict({'args': AttributeDict({'_to': '0x0f60852c32B83416508f875f6C6B7A7B002d20fE',
#    '_amount': 5000000000000000000}),
#   'event': 'CollateralSent',
#   'logIndex': 302,
#   'transactionIndex': 103,
#   'transactionHash': HexBytes('0x8031852a08863db6c9f3275976ee1c59902caeb6c3a29539632880c751cd90fc'),
#   'address': '0xe0e255FD5281bEc3bB8fa1569a20097D9064E445',
#   'blockHash': HexBytes('0x68259c8892b55b1517e3b0b3de2698c3e25cb7fb64289d888352843861432014'),
#   'blockNumber': 18465806}),
#  AttributeDict({'args': AttributeDict({'_to': '0x2F2F665974261C4129b1DC6c359BD259CD66f78A',
#    '_amount': 2000000000000000000}),
#   'event': 'CollateralSent',
#   'logIndex': 502,
#   'transactionIndex': 29,
#   'transactionHash': HexBytes('0xa6cb7823215d2a9ea122a40978d776aa2205c04a4ba90bc38b74ab9c898a84a6'),
#   'address': '0xe0e255FD5281bEc3bB8fa1569a20097D9064E445',
#   'blockHash': HexBytes('0xe57dc3f46b6df36a85678ba4d015f8c8384f46080d65089a40a5db65533f480a'),
#   'blockNumber': 18474156}),
#  AttributeDict({'args': AttributeDict({'_to': '0x9F041fBbc6fd007115dae9BD1cE6001B26747797',
#    '_amount': 730291632784670650}),
#   'event': 'CollateralSent',
#   'logIndex': 260,
#   'transactionIndex': 149,
#   'transactionHash': HexBytes('0xa40d200cfa98e4d402c16a211e6b57e6ed0cfcf9de54898739cae2ad81de7375'),
#   'address': '0xe0e255FD5281bEc3bB8fa1569a20097D9064E445',
#   'blockHash': HexBytes('0x84017185a5989f972b8fc36c911e6bc74889f654a4921e837f2fef95f6cadd6b'),
#   'blockNumber': 18475366}),
#  AttributeDict({'args': AttributeDict({'_to': '0x9F041fBbc6fd007115dae9BD1cE6001B26747797',
#    '_amount': 1535508799586915041}),
#   'event': 'CollateralSent',
#   'logIndex': 82,
#   'transactionIndex': 32,
#   'transactionHash': HexBytes('0xf1ea240bbc06b5cf0b56955ac90d73fe80bbd9d4b562094eeacdd1f560dc3e4f'),
#   'address': '0xe0e255FD5281bEc3bB8fa1569a20097D9064E445',
#   'blockHash': HexBytes('0xe4d80fa4c077ea86c542638d6c063aac2fa1e05e16ccec9b37a0f144a35b3e71'),
#   'blockNumber': 18475396}),
#  AttributeDict({'args': AttributeDict({'_to': '0x17bB6b65B7B5BD3651782CCF2e01c2c9c34ea0Fb',
#    '_amount': 268147242575030277145}),
#   'event': 'CollateralSent',
#   'logIndex': 207,
#   'transactionIndex': 99,
#   'transactionHash': HexBytes('0x824fbf4d606fc808ebe4eb78b8fa5409966623ac33975a530c723278b0fe82a7'),
#   'address': '0xe0e255FD5281bEc3bB8fa1569a20097D9064E445',
#   'blockHash': HexBytes('0xe647597dd7a055e982281f2ca0ddc7a922db248f6bef56e84ddfe166f2ff23d7'),
#   'blockNumber': 18479321}),
#  AttributeDict({'args': AttributeDict({'_to': '0xfce0413BAD4E59f55946669E678EccFe87777777',
#    '_amount': 1837797528357173321}),
#   'event': 'CollateralSent',
#   'logIndex': 451,
#   'transactionIndex': 198,
#   'transactionHash': HexBytes('0xf4c02e1cc953620a722f04227a91766c3627abc5a9df63ae6f86637e7f869e7d'),
#   'address': '0xe0e255FD5281bEc3bB8fa1569a20097D9064E445',
#   'blockHash': HexBytes('0x3fbf0b0fbab1eb4190f1a9cdaba86cb483bdcbd610b6910bf20dbbf0e9a33b5e'),
#   'blockNumber': 18480921}),
#  AttributeDict({'args': AttributeDict({'_to': '0x37A530552cA9df0533D317A292DcC8A582776AA0',
#    '_amount': 46523539621469287876}),
#   'event': 'CollateralSent',
#   'logIndex': 371,
#   'transactionIndex': 259,
#   'transactionHash': HexBytes('0x9e5d17b3d8c1f3abcd041621f4484c3c6da61d18834eaf736dbb87ed88daaa48'),
#   'address': '0xe0e255FD5281bEc3bB8fa1569a20097D9064E445',
#   'blockHash': HexBytes('0xac29c445bff3345a890cc6ad4d237b160a25222a7b8302a6175aa595a888092d'),
#   'blockNumber': 18481218}),
#  AttributeDict({'args': AttributeDict({'_to': '0x6f9BB7e454f5B3eb2310343f0E99269dC2BB8A1d',
#    '_amount': 73033360950709602629}),
#   'event': 'CollateralSent',
#   'logIndex': 237,
#   'transactionIndex': 83,
#   'transactionHash': HexBytes('0xc9c04ca376dc50881b4a8dbe75a56f3c3ff7148603a38accbe4d575fd4bf94b1'),
#   'address': '0xe0e255FD5281bEc3bB8fa1569a20097D9064E445',
#   'blockHash': HexBytes('0xf6c4331e0619e3433a35a673cfd3000b83f5dbb970988b992c9e21d99c1737ad'),
#   'blockNumber': 18481879}),
#  AttributeDict({'args': AttributeDict({'_to': '0x2848E353cC7681bE7C7D5a6884d4B5508a056d11',
#    '_amount': 5605882281167259386}),
#   'event': 'CollateralSent',
#   'logIndex': 300,
#   'transactionIndex': 97,
#   'transactionHash': HexBytes('0x3fe8215c527b19be750c8127fb86d6dc9ac88fd4c8a65179c0d9c5d193b7ffc2'),
#   'address': '0xe0e255FD5281bEc3bB8fa1569a20097D9064E445',
#   'blockHash': HexBytes('0x716a8b1952886a2bf3255b959bf9dc58beac1bc8d104edeed305ce62af432754'),
#   'blockNumber': 18482320}),
#  AttributeDict({'args': AttributeDict({'_to': '0xd5B12178161244cD1ac9EE4857B53f0B6e7c5a46',
#    '_amount': 2080143166180159048}),
#   'event': 'CollateralSent',
#   'logIndex': 701,
#   'transactionIndex': 172,
#   'transactionHash': HexBytes('0xa56c2e50023a91edc6577350d98befa878bee5e9df2481246c04d228f2da853c'),
#   'address': '0xe0e255FD5281bEc3bB8fa1569a20097D9064E445',
#   'blockHash': HexBytes('0x672460d95eec78af2a2bac746c895e5509fa9d2b3953785f997c8608f09c19d5'),
#   'blockNumber': 18482670}),
#  AttributeDict({'args': AttributeDict({'_to': '0xa362a6B387A80180286ef40d8e6eC6Ca2657A9fa',
#    '_amount': 16926112207293355664}),
#   'event': 'CollateralSent',
#   'logIndex': 163,
#   'transactionIndex': 63,
#   'transactionHash': HexBytes('0x0e152d04417bf4d6423f4cbd6b74a082b0c6ee9e46b27589b1c7c5394dead879'),
#   'address': '0xe0e255FD5281bEc3bB8fa1569a20097D9064E445',
#   'blockHash': HexBytes('0x662d702ff238e321cf879dbd1718ccecd7efd2147edeccfa371c679ff66b26b0'),
#   'blockNumber': 18482725}),
#  AttributeDict({'args': AttributeDict({'_to': '0xc7f91e6650Fe21791B1f8af864eD019B6853294E',
#    '_amount': 2306164857308293067}),
#   'event': 'CollateralSent',
#   'logIndex': 218,
#   'transactionIndex': 74,
#   'transactionHash': HexBytes('0x422717cd6a982ae14d2835d1f248b47753ac43c0178c348a8ebffdd0bcde9171'),
#   'address': '0xe0e255FD5281bEc3bB8fa1569a20097D9064E445',
#   'blockHash': HexBytes('0x80861e7bc90877ab3cf5941323b9c72dcf48cc1ae91808bd77f8e8b5a6d1101a'),
#   'blockNumber': 18482748}),
#  AttributeDict({'args': AttributeDict({'_to': '0x371439FC338b786b888413dcDF5c594775b68cb2',
#    '_amount': 3653186145881729244}),
#   'event': 'CollateralSent',
#   'logIndex': 239,
#   'transactionIndex': 87,
#   'transactionHash': HexBytes('0x7f7b73c6e1163265a87e001fe41857bd8e642b0a2181ae57252440cb1855dd45'),
#   'address': '0xe0e255FD5281bEc3bB8fa1569a20097D9064E445',
#   'blockHash': HexBytes('0x779a244fb5f51dc48de80e406b28d5030a867fec40150bdc9147dc6ef6a3028b'),
#   'blockNumber': 18482850}),
#  AttributeDict({'args': AttributeDict({'_to': '0x2f75fFe98046E4a55Fa79daf97B2730d7e707186',
#    '_amount': 2420000000000000000}),
#   'event': 'CollateralSent',
#   'logIndex': 396,
#   'transactionIndex': 189,
#   'transactionHash': HexBytes('0xb37b28bd4d696016c08b4b77d43794b02e9b86971d5a4e7ee2130d99aee08719'),
#   'address': '0xe0e255FD5281bEc3bB8fa1569a20097D9064E445',
#   'blockHash': HexBytes('0x5f931a44f0274eb1391441f6c8fb2c0f847cf26fedd9215396e35c42a458d7a8'),
#   'blockNumber': 18483493}),
#  AttributeDict({'args': AttributeDict({'_to': '0x8F0446d4461F5C6c37545d8C07Ea6eD3Ba4f6EB4',
#    '_amount': 1644014011247718415}),
#   'event': 'CollateralSent',
#   'logIndex': 286,
#   'transactionIndex': 140,
#   'transactionHash': HexBytes('0xccf19099060325525dc0313d5324b2a2d3628ee03492267a518b7ed74e1d2cd7'),
#   'address': '0xe0e255FD5281bEc3bB8fa1569a20097D9064E445',
#   'blockHash': HexBytes('0xe598d4a4092fc6d7e2de5e56772cd4fca44483e8881f54d34c31e0a99a3ce000'),
#   'blockNumber': 18483823}),
#  AttributeDict({'args': AttributeDict({'_to': '0xa91564db5F128F1ef17448CcD06927aa99523951',
#    '_amount': 2000000000000000000}),
#   'event': 'CollateralSent',
#   'logIndex': 187,
#   'transactionIndex': 84,
#   'transactionHash': HexBytes('0x1b8c76b3b2d009f63978c1271a68e7c4b9d9e9f37f6bbdf807e265d8480986e8'),
#   'address': '0xe0e255FD5281bEc3bB8fa1569a20097D9064E445',
#   'blockHash': HexBytes('0x1708a13251c6d15f77ee0ba5a0e6e738c2dffafbfbf436681bc47cfe136d3c93'),
#   'blockNumber': 18483936}),
#  AttributeDict({'args': AttributeDict({'_to': '0x3F3f4e8738313D996a735b91419940DaaEA0C4C7',
#    '_amount': 5891749479213529656}),
#   'event': 'CollateralSent',
#   'logIndex': 374,
#   'transactionIndex': 169,
#   'transactionHash': HexBytes('0xbf373ce4b5cf4f10dc1e52b3f9a888abd71f1603513b4db32a4def1383c9a06c'),
#   'address': '0xe0e255FD5281bEc3bB8fa1569a20097D9064E445',
#   'blockHash': HexBytes('0xf05418e607ecef3f5c7c33c9a100cb6237f103b03190e3a75f939605017087b4'),
#   'blockNumber': 18484181}),
#  AttributeDict({'args': AttributeDict({'_to': '0x60B0FBa5B289800743B35aD8be16CDDEDE2bD67f',
#    '_amount': 2500332947337107973}),
#   'event': 'CollateralSent',
#   'logIndex': 400,
#   'transactionIndex': 143,
#   'transactionHash': HexBytes('0xd5bd0e782fb3a1adcdc9919a4129e5414db3e7072aaa846fcf54ad75af5ff3bc'),
#   'address': '0xe0e255FD5281bEc3bB8fa1569a20097D9064E445',
#   'blockHash': HexBytes('0x12e06531566f21fdf05047e47a556f883f1597d35838d0d3cc7e7003f3834c54'),
#   'blockNumber': 18484467}),
#  AttributeDict({'args': AttributeDict({'_to': '0x48A1514b1464565AF5474d8449309f9DE00A3984',
#    '_amount': 2500315692561963723}),
#   'event': 'CollateralSent',
#   'logIndex': 395,
#   'transactionIndex': 115,
# ...
#   'event': 'CollateralSent',
#   'logIndex': 293,
#   'transactionIndex': 136,
#   'transactionHash': HexBytes('0xb1f94194d996eafa38c1374abe06485fe602a570f1b6a9babf24328b6f1ace3a'),
#   'address': '0xe0e255FD5281bEc3bB8fa1569a20097D9064E445',
#   'blockHash': HexBytes('0x6927ec8bb53aa60e942ac1ef3684cf3d729eb38c51aad8aa3669e90807c5b0c5'),
#   'blockNumber': 19532630}),
#  AttributeDict({'args': AttributeDict({'_to': '0x7C022A1B89050Ce82d2EdA14Cb06de02bA1C7f5A',
#    '_amount': 17253997590298194173}),
#   'event': 'CollateralSent',
#   'logIndex': 277,
#   'transactionIndex': 82,
#   'transactionHash': HexBytes('0x68b2c438b0c5dcb3db74acee489647ff3daa1741da9bb605d1aec59e50361de9'),
#   'address': '0xe0e255FD5281bEc3bB8fa1569a20097D9064E445',
#   'blockHash': HexBytes('0x694b891f166f0a2f509c69efddcdd143258305816008373c33667338c7c7712d'),
#   'blockNumber': 19533053}),
#  AttributeDict({'args': AttributeDict({'_to': '0x95f47f78870073aD4ac1Cb21D3b29038346884B4',
#    '_amount': 1995485324075946097}),
#   'event': 'CollateralSent',
#   'logIndex': 265,
#   'transactionIndex': 149,
#   'transactionHash': HexBytes('0x80904d3464a13bf29f05ebf62c6a3449719fa6aaef949b71c2451a18ffba20e4'),
#   'address': '0xe0e255FD5281bEc3bB8fa1569a20097D9064E445',
#   'blockHash': HexBytes('0x163e703beaf3c23c80bed69f358f9a22362e473b7ff7874d1f41208da34dcd68'),
#   'blockNumber': 19533110}),
#  AttributeDict({'args': AttributeDict({'_to': '0x7C022A1B89050Ce82d2EdA14Cb06de02bA1C7f5A',
#    '_amount': 48911132776894814394}),
#   'event': 'CollateralSent',
#   'logIndex': 271,
#   'transactionIndex': 152,
#   'transactionHash': HexBytes('0xc15bd2d8d4fe10a5021ad6974a011bdcc6b7ad10dfde6655a747796bec9b3412'),
#   'address': '0xe0e255FD5281bEc3bB8fa1569a20097D9064E445',
#   'blockHash': HexBytes('0x95ea15996226bc628cea83914e5acb280d2a4057ec7f32faea4023cbbe123994'),
#   'blockNumber': 19533202}),
#  AttributeDict({'args': AttributeDict({'_to': '0xf16D62012eE210aF984B816a6C8c0CC47EeB65E4',
#    '_amount': 2510379464394486413}),
#   'event': 'CollateralSent',
#   'logIndex': 38,
#   'transactionIndex': 39,
#   'transactionHash': HexBytes('0x008637a755c7263adf46f5e4bc0108e57a11144cee8b1b1b36ea8b92777f73ed'),
#   'address': '0xe0e255FD5281bEc3bB8fa1569a20097D9064E445',
#   'blockHash': HexBytes('0xda5fbe2b2b8cd906d1ce47c4c317d7506edc302e5a75130eee794d62bce50ba9'),
#   'blockNumber': 19534157}),
#  AttributeDict({'args': AttributeDict({'_to': '0x8bb18f1eeB8d170F4edfE2C5D008986171B4e572',
#    '_amount': 6410778869726787850}),
#   'event': 'CollateralSent',
#   'logIndex': 281,
#   'transactionIndex': 52,
#   'transactionHash': HexBytes('0x1ab04ca048847caa0008f0914bddf2f15539c3d672e983439045aef4e4b6cc56'),
#   'address': '0xe0e255FD5281bEc3bB8fa1569a20097D9064E445',
#   'blockHash': HexBytes('0xe090c4f0a11bf5b2678110a83b037b37311c1bcd302caa45e06676921cc3f6c7'),
#   'blockNumber': 19534790}),
#  AttributeDict({'args': AttributeDict({'_to': '0x8bb18f1eeB8d170F4edfE2C5D008986171B4e572',
#    '_amount': 2799233110939923288}),
#   'event': 'CollateralSent',
#   'logIndex': 374,
#   'transactionIndex': 239,
#   'transactionHash': HexBytes('0xb4452ca8155937fd4b81e4bf60a194b2bb91ab03e9490856c16a643564560a01'),
#   'address': '0xe0e255FD5281bEc3bB8fa1569a20097D9064E445',
#   'blockHash': HexBytes('0xc47fadf92752d571037ea311025b43343c767f00635308486a563daaa5383188'),
#   'blockNumber': 19534792}),
#  AttributeDict({'args': AttributeDict({'_to': '0x1309c007567a71b393094c21E70bd2647356A352',
#    '_amount': 300000000000000000000}),
#   'event': 'CollateralSent',
#   'logIndex': 95,
#   'transactionIndex': 52,
#   'transactionHash': HexBytes('0xef8e8552299d489359daee92d1fb4784ac882eb5eaf1302f97337ab93d2fe954'),
#   'address': '0xe0e255FD5281bEc3bB8fa1569a20097D9064E445',
#   'blockHash': HexBytes('0xf30cfe3f01bf42c13f5f4490ed26fa071b9abb8964cc9f709729ab2232cad0b1'),
#   'blockNumber': 19536794}),
#  AttributeDict({'args': AttributeDict({'_to': '0x1309c007567a71b393094c21E70bd2647356A352',
#    '_amount': 200000000000000000000}),
#   'event': 'CollateralSent',
#   'logIndex': 222,
#   'transactionIndex': 73,
#   'transactionHash': HexBytes('0x6ab59c0e1424e64d84f738cca276c9445402911a7d25141f9a9ee936253865aa'),
#   'address': '0xe0e255FD5281bEc3bB8fa1569a20097D9064E445',
#   'blockHash': HexBytes('0xebd632db60a364e90b3f0b3327746efeb18c1506b2efe41e14a9ac9ec9bef9df'),
#   'blockNumber': 19536854}),
#  AttributeDict({'args': AttributeDict({'_to': '0x1309c007567a71b393094c21E70bd2647356A352',
#    '_amount': 268832432415797992514}),
#   'event': 'CollateralSent',
#   'logIndex': 175,
#   'transactionIndex': 78,
#   'transactionHash': HexBytes('0xa07c321a5282c3e695d64e5c39f29d49d289958aacb34f56a9be6e4af073761a'),
#   'address': '0xe0e255FD5281bEc3bB8fa1569a20097D9064E445',
#   'blockHash': HexBytes('0xc846a5526ea0951a7c63f5877bd75b3bd3660b7b85df5b61cdca5df2bb574319'),
#   'blockNumber': 19537301}),
#  AttributeDict({'args': AttributeDict({'_to': '0x0ab94C79F986bBf77DF888Ac25e348cc3D7C9aF8',
#    '_amount': 2004977410573901620}),
#   'event': 'CollateralSent',
#   'logIndex': 603,
#   'transactionIndex': 259,
#   'transactionHash': HexBytes('0x6f3f26bc0c64788c8c66453fcecd2ae128232cb3401c0b534c6f04b7fd7d685f'),
#   'address': '0xe0e255FD5281bEc3bB8fa1569a20097D9064E445',
#   'blockHash': HexBytes('0x7e9e793055d48b42bbb812db652de5d0caf956f94e14725e62a9d94b82117d2a'),
#   'blockNumber': 19538495}),
#  AttributeDict({'args': AttributeDict({'_to': '0x1830c41eeDEA4F101688f1aa6b2C2eF9370AD48D',
#    '_amount': 1880704544135431609}),
#   'event': 'CollateralSent',
#   'logIndex': 265,
#   'transactionIndex': 111,
#   'transactionHash': HexBytes('0x0799f9bd5f8b9f4ddc6b1a5fc589125bd390966ca0c25cef6500e570c8539e56'),
#   'address': '0xe0e255FD5281bEc3bB8fa1569a20097D9064E445',
#   'blockHash': HexBytes('0xdd3090c79d1ccf1e78691146efe0903a27f81aa376aba89cf1d7e1142b305942'),
#   'blockNumber': 19538847}),
#  AttributeDict({'args': AttributeDict({'_to': '0xF60bb4D0c89235fb7B700E9F4eF1f29864Aa9aFF',
#    '_amount': 4602127482833198956}),
#   'event': 'CollateralSent',
#   'logIndex': 156,
#   'transactionIndex': 56,
#   'transactionHash': HexBytes('0x62e41b0c074f6e9ee6e9d47432e5f225cfeca77795f60845450bc930864dd043'),
#   'address': '0xe0e255FD5281bEc3bB8fa1569a20097D9064E445',
#   'blockHash': HexBytes('0x7bc1bf04714b01436b710b11c425225be2b758005fc1473110646c35d7a792d7'),
#   'blockNumber': 19539263}),
#  AttributeDict({'args': AttributeDict({'_to': '0xCB16F82E5949975f9Cf229C91c3A6D43e3B32a9E',
#    '_amount': 3570724996579449789923}),
#   'event': 'CollateralSent',
#   'logIndex': 295,
#   'transactionIndex': 147,
#   'transactionHash': HexBytes('0x2b7420ac3b0c4f0298c3131be8ab3a826ad3f81b09ea360e858b0a5617abb475'),
#   'address': '0xe0e255FD5281bEc3bB8fa1569a20097D9064E445',
#   'blockHash': HexBytes('0xaba0916177b5a6ae83c4832201192b0c51fb664df8a5aa1de42edddb19b0d0e9'),
#   'blockNumber': 19539457}),
#  AttributeDict({'args': AttributeDict({'_to': '0x1Fe519fE58D4f2022050EEAEC2aD58E18d7Ae2Ad',
#    '_amount': 5000000000000000000}),
#   'event': 'CollateralSent',
#   'logIndex': 182,
#   'transactionIndex': 106,
#   'transactionHash': HexBytes('0x94c238011872baba1e63dcd83741fb5027df460abe9dd34746c172a11a48d7a9'),
#   'address': '0xe0e255FD5281bEc3bB8fa1569a20097D9064E445',
#   'blockHash': HexBytes('0x04864199becb110105bc25c21d66eb729bf53d3ce25192d814c1d75ca5656b0e'),
#   'blockNumber': 19547179}),
#  AttributeDict({'args': AttributeDict({'_to': '0x1Fe519fE58D4f2022050EEAEC2aD58E18d7Ae2Ad',
#    '_amount': 11451554658457107308}),
#   'event': 'CollateralSent',
#   'logIndex': 166,
#   'transactionIndex': 89,
#   'transactionHash': HexBytes('0x453963e47d62eb640e861edc9ebc66dbb205c0d764281c7a4c30178b0ce437a4'),
#   'address': '0xe0e255FD5281bEc3bB8fa1569a20097D9064E445',
#   'blockHash': HexBytes('0x55b3dd7839e12e812e2d7a1205e34508deb7ce2da8bee4dcdd3980bc049948bd'),
#   'blockNumber': 19547200}),
#  AttributeDict({'args': AttributeDict({'_to': '0x5A6da46839Fe767C8a481a735Af978baa5576944',
#    '_amount': 600000000000000000}),
#   'event': 'CollateralSent',
#   'logIndex': 189,
#   'transactionIndex': 41,
#   'transactionHash': HexBytes('0x8bdeef7cd4f2fa3e96e8d840dcec82050d9539f404cf4bd37fb7a4f0009c495a'),
#   'address': '0xe0e255FD5281bEc3bB8fa1569a20097D9064E445',
#   'blockHash': HexBytes('0xc556f89bdb539356d6cb54ab053a2f1848d9f0a7a1a999b15775bba04e81ff9d'),
#   'blockNumber': 19549284}),
#  AttributeDict({'args': AttributeDict({'_to': '0x5A6da46839Fe767C8a481a735Af978baa5576944',
#    '_amount': 1766136890600888303}),
#   'event': 'CollateralSent',
#   'logIndex': 137,
#   'transactionIndex': 54,
#   'transactionHash': HexBytes('0x127332c9dd6337556cebc594a808f3246234807e6e703a80473ce187123193b1'),
#   'address': '0xe0e255FD5281bEc3bB8fa1569a20097D9064E445',
#   'blockHash': HexBytes('0xe39423c791e6172ea20550fb0fdc3ac0a0dd00fc32cf2cbcaf7bc7e9b807299b'),
#   'blockNumber': 19549310}),
#  AttributeDict({'args': AttributeDict({'_to': '0x6E76b3c45271f0AaC7A2B245AF18a9C883a493Ad',
#    '_amount': 6244303270592470124}),
#   'event': 'CollateralSent',
#   'logIndex': 156,
#   'transactionIndex': 67,
#   'transactionHash': HexBytes('0x0e4fe4b2a7daaa076d94ee6e58ef0ea3db0fa03a4dee9d2ddddfb1de0334a906'),
#   'address': '0xe0e255FD5281bEc3bB8fa1569a20097D9064E445',
#   'blockHash': HexBytes('0x09f1cf2c4689fdb0aa77f578e2676685c1c460605f96b02f40d159b383532f19'),
#   'blockNumber': 19553558}),
#  AttributeDict({'args': AttributeDict({'_to': '0x6E76b3c45271f0AaC7A2B245AF18a9C883a493Ad',
#    '_amount': 2990992654698090153}),
#   'event': 'CollateralSent',
#   'logIndex': 187,
#   'transactionIndex': 52,
#   'transactionHash': HexBytes('0xe69d03bd6188284da5271e5c45181c4bc987924ea0eb0ffb52ad766e550d48f0'),
#   'address': '0xe0e255FD5281bEc3bB8fa1569a20097D9064E445',
#   'blockHash': HexBytes('0x4297f75cbf70c40dbecaacc4cc2330f7c0b3dc2b851a3a55506937f4e853ebca'),
#   'blockNumber': 19553567}),
#  AttributeDict({'args': AttributeDict({'_to': '0xc8484D4A6BaAaA7C31f411b1362145dA109F9B50',
#    '_amount': 2767406157280570175}),
#   'event': 'CollateralSent',
#   'logIndex': 78,
#   'transactionIndex': 28,
#   'transactionHash': HexBytes('0xb135532c067ea6f2f12cd98d006387fd5cab01f536f1a5701ae846b019571950'),
#   'address': '0xe0e255FD5281bEc3bB8fa1569a20097D9064E445',
#   'blockHash': HexBytes('0x21eb7a7494b838e0576c0fb6302f833fe82ccc69db11d63d3586634ea5f36439'),
#   'blockNumber': 19557268}),
#  AttributeDict({'args': AttributeDict({'_to': '0x2D760D867EBebD7DA5B0bE18fed71B4bcC9610Eb',
#    '_amount': 152160292487650199897}),
#   'event': 'CollateralSent',
#   'logIndex': 241,
#   'transactionIndex': 121,
#   'transactionHash': HexBytes('0x07001a0ac4693b5ed51db326fa86229a1b5751a9ca91c7eafa5814dbe9a1e48a'),
#   'address': '0xe0e255FD5281bEc3bB8fa1569a20097D9064E445',
#   'blockHash': HexBytes('0x33a828335b358f39f23e3c332773695295908d32334ed9f1229dea47077b1038'),
#   'blockNumber': 19559873}),
#  AttributeDict({'args': AttributeDict({'_to': '0x8Ac6F2BdDA60196afaaEfea5f95Ef39314cbE2bD',
#    '_amount': 5040914399655846960}),
#   'event': 'CollateralSent',
#   'logIndex': 160,
#   'transactionIndex': 116,
#   'transactionHash': HexBytes('0xe11722627d573667114197d73e842e7244a65f25ae93706c4c496df15f53095a'),
#   'address': '0xe0e255FD5281bEc3bB8fa1569a20097D9064E445',
#   'blockHash': HexBytes('0xd4996935035680aecf74e97a8a639ac95568b32fce251232445b3bfe31010cc1'),
#   'blockNumber': 19564812}),
#  AttributeDict({'args': AttributeDict({'_to': '0x95f47f78870073aD4ac1Cb21D3b29038346884B4',
#    '_amount': 762083657618970895}),
#   'event': 'CollateralSent',
#   'logIndex': 327,
#   'transactionIndex': 169,
#   'transactionHash': HexBytes('0xf7e4559db67ad3c3a4ea7a5ffaf496bbeb7ba7048ae2962643fccd4604621b4b'),
#   'address': '0xe0e255FD5281bEc3bB8fa1569a20097D9064E445',
#   'blockHash': HexBytes('0x3d9d8ad34d0601b2d00a95e4187546a6182b2dd98bcf3cac53d678144ddb98c7'),
#   'blockNumber': 19579779}),
#  AttributeDict({'args': AttributeDict({'_to': '0x4958652CD7a632F4B0Bae0e65c6562c970C1f432',
#    '_amount': 2000000000000000000}),
#   'event': 'CollateralSent',
#   'logIndex': 163,
#   'transactionIndex': 93,
#   'transactionHash': HexBytes('0x564ad305be28ef2ded384ca24ba6706e06448a85da735312fe888542f7709a94'),
#   'address': '0xe0e255FD5281bEc3bB8fa1569a20097D9064E445',
#   'blockHash': HexBytes('0x71523ca3e8655b356b2c217f725035abfbb7379de06b59779745f38db5df19c8'),
#   'blockNumber': 19581307}),
#  AttributeDict({'args': AttributeDict({'_to': '0x45A5341248544a4E880860028550166d3ea27D88',
#    '_amount': 2500000000000000000}),
#   'event': 'CollateralSent',
#   'logIndex': 263,
#   'transactionIndex': 118,
#   'transactionHash': HexBytes('0x375adc59ba32737075c37da71215314c40be80399b9c72ca8201d60e6ad766b1'),
#   'address': '0xe0e255FD5281bEc3bB8fa1569a20097D9064E445',
#   'blockHash': HexBytes('0x91d23f0acd89d71d03de557c950454e5d34775cc26f5bd9c3ab72d53c5878b3a'),
#   'blockNumber': 19584074}),
#  AttributeDict({'args': AttributeDict({'_to': '0x3F3E305C4Ad49271EBDA489dd43d2c8F027d2D41',
#    '_amount': 91734862601224686082}),
#   'event': 'CollateralSent',
#   'logIndex': 247,
#   'transactionIndex': 179,
#   'transactionHash': HexBytes('0xa3f5c114a1e403e825d9cc348dd639a1126f1d61305c3b7581a9bf836819f7b9'),
#   'address': '0xe0e255FD5281bEc3bB8fa1569a20097D9064E445',
#   'blockHash': HexBytes('0x757845f9be13506397573bfcbeae712df5a102c04d337b92105810687030c513'),
#   'blockNumber': 19586813}),
#  AttributeDict({'args': AttributeDict({'_to': '0x1Efb9f8b00b4a5dBF0F779aa032febD4b8F38a94',
#    '_amount': 8002192637389242462}),
#   'event': 'CollateralSent',
#   'logIndex': 116,
#   'transactionIndex': 107,
#   'transactionHash': HexBytes('0x4ee87bbca874162a14bfcf65eba11a88e1f58c26363820b946a74f002cc2ab51'),
#   'address': '0xe0e255FD5281bEc3bB8fa1569a20097D9064E445',
#   'blockHash': HexBytes('0x4cf9ad3bc2295456eb591690151a72ab22b7a46cd8834bdab7ddf92400adc2df'),
#   'blockNumber': 19590400}),
#  AttributeDict({'args': AttributeDict({'_to': '0x5c15ceD59fD964fCFFF2d2F376b4a40b6D1Fce1c',
#    '_amount': 2290936307831773000}),
#   'event': 'CollateralSent',
#   'logIndex': 173,
#   'transactionIndex': 90,
#   'transactionHash': HexBytes('0x36847665521a94fb88caad9ff99b5a0d7a18d333cb191572fe87bca0a21e3528'),
#   'address': '0xe0e255FD5281bEc3bB8fa1569a20097D9064E445',
#   'blockHash': HexBytes('0x04f0421d0dbdc376cee5fa766b4afef9a36bc419dfa3893fca9746b0a954b60f'),
#   'blockNumber': 19604559}),
#  AttributeDict({'args': AttributeDict({'_to': '0xEaa44e71a7723867e20fcc0a17045a5CfF621B8E',
#    '_amount': 4549510035699037054}),
#   'event': 'CollateralSent',
#   'logIndex': 364,
#   'transactionIndex': 273,
#   'transactionHash': HexBytes('0xa5f61cf9507f5c72a89d5397391dcdb38ef5d9291cd087b429988e8058af9249'),
#   'address': '0xe0e255FD5281bEc3bB8fa1569a20097D9064E445',
#   'blockHash': HexBytes('0xcd76a013779c1cd555d78d0cec0628ac11079c77af7f9d9d551dd8c8cfcb5dbc'),
#   'blockNumber': 19613039}),
#  AttributeDict({'args': AttributeDict({'_to': '0x5c15ceD59fD964fCFFF2d2F376b4a40b6D1Fce1c',
#    '_amount': 2741576764724075646}),
#   'event': 'CollateralSent',
#   'logIndex': 114,
#   'transactionIndex': 64,
#   'transactionHash': HexBytes('0x26554f7623bccc8f3c0728f83d5546579b96c6fefb546c267667eb5ad5e1ace5'),
#   'address': '0xe0e255FD5281bEc3bB8fa1569a20097D9064E445',
#   'blockHash': HexBytes('0x3cf845327f006a1685dd5162d7daed1b2c3726c0ded8bd5577072854808936d8'),
#   'blockNumber': 19616933}),
#  AttributeDict({'args': AttributeDict({'_to': '0x5c15ceD59fD964fCFFF2d2F376b4a40b6D1Fce1c',
#    '_amount': 4000000000000000000}),
#   'event': 'CollateralSent',
#   'logIndex': 143,
#   'transactionIndex': 106,
#   'transactionHash': HexBytes('0x5f79409a0bde7ce8ccd4d4aa24fe6e7c33073079dd77c6c6834fd70caf8e5a4e'),
#   'address': '0xe0e255FD5281bEc3bB8fa1569a20097D9064E445',
#   'blockHash': HexBytes('0x61c69620cc9af3cc7a303469941aba1617fb8405e83b6d6f929032c835280a37'),
#   'blockNumber': 19622263}),
#  AttributeDict({'args': AttributeDict({'_to': '0x5c15ceD59fD964fCFFF2d2F376b4a40b6D1Fce1c',
#    '_amount': 85704201770127604563}),
#   'event': 'CollateralSent',
#   'logIndex': 188,
#   'transactionIndex': 80,
#   'transactionHash': HexBytes('0xc44e5f3effef20bc126bea82e20e6915433816aacb9ae309368d3661e73157f9'),
#   'address': '0xe0e255FD5281bEc3bB8fa1569a20097D9064E445',
#   'blockHash': HexBytes('0xe3f927bc4548f9afc329304114f0bba7719bc54a1584d46e4e5822e979a83186'),
#   'blockNumber': 19634940}))

# %%
contract_address, abi_filepath = contract_address_abi_map['PRISMA']
print(contract_address[0], contract_address[1])
print(abi_filepath[0], abi_filepath[1])

with open (abi_filepath[1]) as f:
    abi = json.load(f)
# Out:
# 0x0d6741f1A3A538F78009ca2e3a13F9cB1478B2d0 ./Prisma_TroveManagerNew_ABI.json
# 0xe0e255FD5281bEc3bB8fa1569a20097D9064E445 ./Prisma_TroveManagerOld_ABI.json
