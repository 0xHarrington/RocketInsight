# %%
# Imports
from web3 import HTTPProvider, Web3
from evm_trace import TraceFrame, get_calltree_from_parity_trace, CallType, ParityTraceList

# Link RPC node
web3 = Web3(Web3.HTTPProvider('https://mainnet.infura.io/v3/5f0c4998d7544ee1bb3f0dc297a6821c'))

# Transaction hash to analyze
txn_hash = "0x3e5c89715964584537d16c1b23bc5e710d3094c8f072f002d8e9876d23e1dd3b"

# Get raw trace list
raw_trace_list = web3.manager.request_blocking("trace_transaction", [txn_hash])

# View raw trace
raw_trace_list
# Out:
# [AttributeDict({'action': AttributeDict({'callType': 'call',
#    'from': '0xa59ea3b9fee7a1d1d9c533fe8ae215f97b8e054b',
#    'gas': '0x398a7',
#    'input': '0x69328dec000000000000000000000000ae78736cd615f374d3085123a210448e74fc6393ffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffff000000000000000000000000a59ea3b9fee7a1d1d9c533fe8ae215f97b8e054b',
#    'to': '0x87870bca3f3fd6335c3f4ce8392d69350b4fa4e2',
#    'value': '0x0'}),
#   'blockHash': '0x2862ef4204d8e71115b999d734740c8246c90c3199be0c11cb5c3ac4f730824f',
#   'blockNumber': 16628078,
#   'result': AttributeDict({'gasUsed': '0x29cd7',
#    'output': '0x0000000000000000000000000000000000000000000000000c422fca45bb5236'}),
#   'subtraces': 1,
#   'traceAddress': [],
#   'transactionHash': '0x3e5c89715964584537d16c1b23bc5e710d3094c8f072f002d8e9876d23e1dd3b',
#   'transactionPosition': 273,
#   'type': 'call'}),
#  AttributeDict({'action': AttributeDict({'callType': 'delegatecall',
# ...

# %%
# Get calltree from parity trace
trace_list = ParityTraceList.model_validate(raw_trace_list)
tree = get_calltree_from_parity_trace(trace_list)
tree
# Out:
# CALL: 0x87870Bca3F3fD6335C3F4ce8392D69350B4fA4E2.<0x69328dec> [171223 gas]
# └── DELEGATECALL: 0xfCc00A1e250644d89AF0df661bC6f04891E21585.<0x69328dec> [166162 gas]
#     ├── STATICCALL: 0x2f39d218133AFaB8F2B819B1066c7E434Ad94E9e.<0xfca513a8> [2402 gas]
#     └── DELEGATECALL: 0x666835b336a3A5198B2895D94109131d1b23Ad11.<0x186dea44> [152541 gas]
#         ├── STATICCALL: 0xae8593DD575FE29A9745056aA91C4b746eee62C8.<0xb1bf962d> [7468 gas]
#         │   └── DELEGATECALL: 0xaC725CB59D16C81061BDeA61041a8A5e73DA9EC6.<0xb1bf962d> [2419 gas]
#         ├── STATICCALL: 0x1d1906f909CAe494c7441604DAfDDDbD0485A925.<0x79774338> [9982 gas]
#         │   └── DELEGATECALL: 0x15C5620dfFaC7c7366EED66C20Ad222DDbB1eD57.<0x79774338> [4921 gas]
#         ├── STATICCALL: 0xCc9EE9483f662091a1de4795249E24aC0aC2630f.<0x1da24f3e> [7646 gas]
#         │   └── DELEGATECALL: 0x7EfFD7b47Bfd17e52fB7559d3f924201b9DbfF3d.<0x1da24f3e> [2626 gas]
# ...
